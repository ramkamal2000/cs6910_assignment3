# %% [markdown]
# # TO DO
# 1. Bearm search with log and normalization
# 2. Change structure of test dataset
# 3. Bleu score calculation
# 4. Training, saving and loading best model

# %% [markdown]
# # TO DO ATTENTION
# 1.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.10.30)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.1.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.16)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.0->wandb) (56.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2020.12.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.0; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)

# %%
import tarfile
import os
import pandas as pd
import keras
import numpy as np
import wandb
import tensorflow as tf
import shutil
from keras import layers
from keras.layers import LSTM, Dense, Embedding, Input
from keras.models import Model
from keras.utils.vis_utils import plot_model
from tqdm.auto import tqdm
from keras.layers import Lambda
from keras import backend as K
import datetime
from math import ceil
from pprint import pprint

# %%
# !wget -nc https://storage.googleapis.com/gresearch/dakshina/dakshina_dataset_v1.0.tar

if not os.path.isdir('/content/dakshina_dataset_v1.0'):
  tarfile.open("/content/dakshina_dataset_v1.0.tar").extractall()
# Out:
# File ‘dakshina_dataset_v1.0.tar’ already there; not retrieving.

# %%
wandb.login(key='14394907543f59ea21931529e34b4d80d2ca8c9c')
# Out:
# wandb: Currently logged in as: ramkamal (use `wandb login --relogin` to force relogin)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publically.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Loading Data

# %%
class data_loader():

  @staticmethod
  def _load_raw_df(languages = ['ta']):
    lex = dict()
    lex['train'], lex['val'], lex['test'] = [], [], [] 
    column_names = ['output', 'input', 'count']
    
    for la in languages:
      lex['train'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.train.tsv', sep='\t', header=None, names=column_names))
      lex['val'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.dev.tsv', sep='\t', header=None, names=column_names))
      lex['test'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.test.tsv', sep='\t', header=None, names=column_names))

    lex['train'] = pd.concat(lex['train'])
    lex['val'] = pd.concat(lex['val'])
    lex['test'] = pd.concat(lex['test'])

    return lex    

  @staticmethod
  def _make_final_df(lex):
    
    for div in ['train', 'val']:
    
      # removing non max transliterations
      idx = lex[div].groupby(['input'])['count'].transform(max) == lex[div]['count']
      lex[div] = lex[div][idx].reset_index(drop=True)

      # calclulating difference in lengths of various transliterations
      lex[div]['input_len'] = lex[div].apply(lambda x: len(str(x['input'])), axis=1)
      lex[div]['output_len'] = lex[div].apply(lambda y: len(str(y['output'])), axis=1)
      lex[div]['mod_dif'] = lex[div].apply(lambda z: abs(z['input_len'] - z['output_len']), axis=1) 

      # removing transliterations that vary by a lot in length
      idx = lex[div].groupby(['input'])['mod_dif'].transform(min) == lex[div]['mod_dif']
      lex[div] = lex[div][idx].reset_index(drop=True)

      # removing duplicates if any remain
      lex[div].drop_duplicates(subset='input', keep='first', inplace=True)

      # removing redundant columns
      lex[div].drop(labels=['count', 'input_len', 'output_len', 'mod_dif'], inplace=True, axis=1)

      # shuffling the dataset i.e. rows of the dataset
      lex[div] = lex[div].sample(frac=1)
      lex[div] = lex[div][idx].reset_index(drop=True)

    ##### something for the test dataset

    return lex

  @staticmethod
  def _generate_batch(X, y, data_dict, num_decoder_tokens, batch_size = 1):

    while True:
        for j in range(0, len(X), batch_size):
            
            # placeholder data structures
            encoder_input_data = np.zeros((batch_size, data_dict['max_source_length']),dtype='float32')
            decoder_input_data = np.zeros((batch_size, data_dict['max_target_length']),dtype='float32')
            decoder_target_data = np.zeros((batch_size, data_dict['max_target_length'], num_decoder_tokens),dtype='float32')

            # assessing one batch at a time
            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):

                for t, word in enumerate(input_text):
                  encoder_input_data[i, t] = word
                for t, word in enumerate(target_text):
                    if t<len(target_text)-1:
                        # decoder input sequence
                        # does not include the <EOW> token
                        decoder_input_data[i, t] = word 
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the <SOW> token
                        decoder_target_data[i, t - 1, word] = 1.
                    
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

  @staticmethod
  def _generate_batch_greedy(X, y, data_dict, num_decoder_tokens, batch_size = 1):

    while True:
        for j in range(0, len(X), batch_size):

            # placeholder data structures
            encoder_input_data = np.zeros((batch_size, data_dict['max_source_length']),dtype='float32')
            decoder_input_data = np.zeros((batch_size, 1),dtype='float32')
            decoder_target_data = np.zeros((batch_size, data_dict['max_target_length'], num_decoder_tokens),dtype='float32')
            
            # assessing one batch at a time
            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
                for t, word in enumerate(input_text):
                  encoder_input_data[i, t] = word
                for t, word in enumerate(target_text):
                    if t==0 :
                        decoder_input_data[i, t] = 1 # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        decoder_target_data[i, t - 1, word] = 1.
                    
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %%
class Tokenizer:

  def __init__(self, df):

    self.start_token = '<SOW>'
    self.stop_token = '<EOW>'
    self.unknown_token = '<UNK>'

    self.input_corpus = [self.start_token, self.stop_token, self.unknown_token]
    self.output_corpus = [self.start_token, self.stop_token, self.unknown_token]

    input_words = df.input.tolist()
    output_words = df.output.tolist()

    for word in input_words:
      tokens = str(word)
      for token in tokens:
        if token not in self.input_corpus:
          self.input_corpus.append(token)

    for word in output_words:
      tokens = str(word)
      for token in tokens:
        if token not in self.output_corpus:
          self.output_corpus.append(token)
    
    self.encode_dict_input = {self.input_corpus[i] : i+1 for i in range(len(self.input_corpus))}
    self.decode_dict_input = {k:v for v,k in self.encode_dict_input.items()}
    
    
    self.encode_dict_output = {self.output_corpus[i] : i+1 for i in range(len(self.output_corpus))}
    self.decode_dict_output = {k:v for v,k in self.encode_dict_output.items()}
    self.decode_dict_output.update({2:''})

  # takes in lists of words and returns lists of integers
  def encode(self, X, mode='input'):

    if (mode=='input'):
      input_list = []
      for word in X:
        word = str(word)
        integer_list =np.array([self.encode_dict_input.get(token, self.encode_dict_input[self.unknown_token]) for token in word])
        input_list.append(integer_list)
      
      return input_list
    
    if (mode=='output'):
      output_list = []
      for word in X:
        word = str(word)
        integer_list = np.array([self.encode_dict_output[self.start_token]] + [self.encode_dict_output.get(token, self.encode_dict_output[self.unknown_token]) for token in word] + [self.encode_dict_output[self.stop_token]])
        output_list.append(integer_list)
      
      return output_list
    
  # takes in lists of integers and returns lists of words
  def decode(self, X, mode='input'):

    if (mode=='input'):
      input_list = []
      for integers in X:
        token_list = [self.decode_dict_input.get(integer, '') for integer in integers] 
        input_list.append(''.join(token_list))
      
      return input_list

    if (mode=='output'):
      output_list = []
      for integers in X:
        token_list = [self.decode_dict_output.get(integer, '') for integer in integers[1:-1]] 
        output_list.append(''.join(token_list))
      
      return output_list

# %%
def return_data_dict(languages=['ta'], batch_size=32):

  lex = data_loader._load_raw_df(languages)
  lex = data_loader._make_final_df(lex)

  data_dict = dict()

  df_train = lex['train']
  df_val = lex['val']
  df_test = lex['test']

  tk = Tokenizer(df_train)

  data_dict['in_size'] = len(tk.input_corpus) + 1
  data_dict['out_size'] = len(tk.output_corpus) + 1

  X_train = tk.encode(df_train.input.tolist(), mode='input')
  Y_train = tk.encode(df_train.output.tolist(), mode='output')
  
  X_val = tk.encode(df_val.input.tolist(), mode='input')
  Y_val = tk.encode(df_val.output.tolist(), mode='output')

  data_dict['train'], data_dict['val'], data_dict['test']= dict(), dict(), dict()


  data_dict['train']['df'] = df_train
  data_dict['val']['df'] = df_val
  data_dict['test']['df'] = df_test


  data_dict['train']['max_source_length'] = np.max(np.array([len(x) for x in X_train]))
  data_dict['train']['max_target_length'] = np.max(np.array([len(x) for x in Y_train]))
  
  data_dict['val']['max_source_length'] = np.max(np.array([len(x) for x in X_val]))
  data_dict['val']['max_target_length'] = np.max(np.array([len(x) for x in Y_test]))

  data_dict['max_source_length'] = max(data_dict['train']['max_source_length'], data_dict['val']['max_source_length'])
  data_dict['max_target_length'] = max(data_dict['train']['max_target_length'], data_dict['val']['max_target_length'])

  data_dict['train']['batch'] = data_loader._generate_batch(X_train, Y_train, data_dict, data_dict['out_size'], batch_size)
  data_dict['train']['batch_greedy'] = data_loader._generate_batch_greedy(X_train, Y_train, data_dict, data_dict['out_size'], batch_size)
  
  data_dict['val']['batch'] = data_loader._generate_batch(X_val, Y_val, data_dict, data_dict['out_size'], batch_size)
  data_dict['val']['batch_greedy'] = data_loader._generate_batch_greedy(X_val, Y_val, data_dict, data_dict['out_size'], batch_size)

  data_dict['tokenizer'] = tk

  return data_dict

# %%
dict_data_dict = dict()

for batch_size in [32]:
  dict_data_dict.update({batch_size: return_data_dict(batch_size=batch_size)})

data_dict = list(dict_data_dict.values())[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # Question 1

# %%
def decode_sequence_beam(input_seq, k, encoder_model, decoder_model, tk, max_target_length=20, getall=False):
    # encode the input as state vectors
    states_value = encoder_model.predict(input_seq,batch_size=1,use_multiprocessing=True)
    # generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # populate the first character of target sequence with the start character.
    target_seq[0, 0] = 1 
    run_condition = [True for i in range(k)]
    # print(len(states_value))
    # print([target_seq] + [states_value])
    results, *states_values_temp = decoder_model.predict([target_seq] + [states_value])
    output_tokens = results

    states_values_k = [states_values_temp for i in range(k)]
    #get topk indices
    ind = np.argpartition(np.array(output_tokens[0, -1, :]), -k)[-k:]
    bestk_ind = ind
    output_tokens = np.array(output_tokens[0, -1, :])
    bestk_prob = output_tokens[ind]
    bestk_tot = [[1,bestk_ind[i]] for i in range(k)]
    # print(bestk_tot)

    
    while any(run_condition):
        bestk_tot_new = []
        bestk_prob_new = []
        states_values_k_new = []
        for i in range(k) :
            if run_condition[i] :
                a = bestk_tot[i]
                b = bestk_prob[i]
                target_seq[0,0] = a[-1]
                results,*states_values_temp = decoder_model.predict([target_seq] + states_values_k[i],batch_size=1)
                output_tokens = results

                states_values_k_temp = [states_values_temp for m in range(k)]

                states_values_k_new += states_values_k_temp
                ind = np.argpartition(np.array(output_tokens[0, -1, :]), -k)[-k:]
                bestk_ind = ind
                output_tokens = np.array(output_tokens[0, -1, :])
                bestk_prob_temp = output_tokens[ind]
                bestk_tot_temp = [a+[bestk_ind[j]] for j in range(k)]
                bestk_prob_temp2 = [b*bestk_prob_temp[j] for j in range(k)]
                bestk_prob_new += bestk_prob_temp2
                bestk_tot_new += bestk_tot_temp
            
            else :
                a = bestk_tot[i]
                b = bestk_prob[i]
                bestk_tot_new += [bestk_tot[i]]
                bestk_prob_new += [b]
                states_values_k_new += [states_values_k[i]]

        bestk_prob_new = np.array(bestk_prob_new)
        # print(len(bestk_prob_new),len(bestk_tot_new),len(states_values_k_new))
        ind = np.argpartition(bestk_prob_new,-k)[-k:]
        bestk_tot = [bestk_tot_new[i] for i in ind]
        states_values_k = [states_values_k_new[i] for i in ind]
        bestk_prob = bestk_prob_new[ind]
        run_condition = []
        for i in range(k) :
            a = bestk_tot[i]
            b = bestk_prob[i]
            if a[-1]!= 2 and len(a)<=max_target_length :
              run_condition.append(True)
            else :
              run_condition.append(False)

        # print(bestk_tot)

    final_words = []
    best_word = []
    best = 0.0
    for i in range(k) :
      a = bestk_tot[i]
      b = bestk_prob[i]
      final_words += [a]
      if b > best :
        best_word = [a]

    if getall :
      return (tk.decode(final_words,'output'),best_word)
    else :
      return final_words,best_word

# %%
class rnn():

  def __init__(self, params):
    
    num_encode_layers = params['num_encode_layers']
    num_decode_layers = params['num_decode_layers']
    data_dict = params['data_dict']
    in_size = params['data_dict']['in_size']
    out_size = params['data_dict']['out_size']
    cell_type = params['cell_type']
    dropout = params['dropout']
    embed_size = params['embed_size']
    rep_size = params['rep_size']
        
    ###################### ENCODER NETWORK ######################
    
    encoder_inputs = Input(shape=(None,))
    x = Embedding(in_size, embed_size ,mask_zero=True)(encoder_inputs)

    encoder_layers = []
    
    for j in range(num_encode_layers-1) :   
      curr_layer = getattr(layers, cell_type)(rep_size, dropout=dropout, return_sequences=True)
      encoder_layers.append(curr_layer)
      x = curr_layer(x)

    curr_layer = getattr(layers, cell_type)(rep_size, dropout=dropout, return_state=True)
    encoder_layers.append(curr_layer)
    x, *encoder_states = curr_layer(x)

    ###################### DECODER NETWORK ######################

    decoder_inputs = Input(shape=(None,))

    decoder_embedding =  Embedding(out_size, embed_size, mask_zero=True)
    x = decoder_embedding(decoder_inputs)

    decoder_layers = []    
    
    for j in range(num_decode_layers) :
      curr_layer = getattr(layers, cell_type)(rep_size,dropout=dropout,return_state=True, return_sequences=True)
      decoder_layers.append(curr_layer)
      x, *decoder_states = curr_layer(x, initial_state=encoder_states)

    decoder_dense = Dense(units=out_size, activation='softmax')
    decoder_outputs = decoder_dense(x)

    # define the model that will turn `encoder_inputs` & `decoder_inputs` into `decoder_outputs`
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

    ##### ????? ????? ????? ????? ????? ????? ????? ????? ????? ????? 
    self.model = model
    self.encoder_inputs = encoder_inputs
    self.encoder_layers = encoder_layers
    self.decoder_inputs = decoder_inputs
    self.decoder_embedding = decoder_embedding
    self.decoder_layers = decoder_layers
    self.decoder_dense = decoder_dense
    self.encoder_states = encoder_states
    self.params = params
    self.details = {
        'model' : self.model,
        'encoder_inputs' : self.encoder_inputs,
        'encoder_layers' :self.encoder_layers ,
        'decoder_inputs' :self.decoder_inputs ,
        'decoder_embedding' : self.decoder_embedding,
        'decoder_layers' : self.decoder_layers,
        'decoder_dense' : self.decoder_dense,
        'encoder_states' : self.encoder_states ,
        'params' :self.params,
    }

  def compile_and_fit(self, data_dict, params):

    # compiling the model
    self.model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    
    # printing the summary of the model
    summary = self.model.summary()

    # plotting the model figure
    plot = plot_model(self.model, show_shapes=True)
    
    # total training samples
    train_samples = len(data_dict['train']['df'])

    # total validation samples
    val_samples = len(data_dict['val']['df'])    
    
    # batch size
    batch_size = params['batch_size']

    # number of epochs
    num_epochs = params['num_epochs']

    # training the model
    run_details = self.model.fit_generator(generator = data_dict['train']['batch'],
                                           steps_per_epoch = train_samples//batch_size,
                                           epochs=num_epochs,
                                           callbacks=[
                                                      wandb.keras.WandbCallback()
                                                      ],
                                           validation_data = data_dict['val']['batch'], 
                                           validation_steps = val_samples//batch_size
                                          )

    return {
        'run_details' : run_details
    }

# %%
class rnn_second() :
  def __init__(self, details) :

    # copying required details
    self.details = details

    # copying decoder state input
    decoder_state_input = self.details['encoder_states']

    decoder_inputs = Input(shape=(1,))

    # copying hidden representation size
    rep_size = self.details['params']['rep_size']

    # copying decoder inputs
    decoder_inputs = self.details['decoder_inputs']

    # the decoder model
    x = self.details['decoder_embedding'](decoder_inputs)
  
    all_outputs = []
    for _ in range(self.details['params']['data_dict']['max_target_length']) :
        for layer in self.details['decoder_layers'] :
            x, *decoder_states = layer(x, initial_state=decoder_state_input)

        x = self.details['decoder_dense'](x)

        # appending the softmax output
        all_outputs.append(x)

        # taking the argmax to feed into the next time step
        # print("Hello ",tf.math.argmax(x, 2))
        # if int(tf.math.argmax(x, 2))==2:
        #     x = 0
        # else:
        #     x = tf.math.argmax(x, 2)
        x = tf.math.argmax(x, 2) 
        x = self.details['decoder_embedding'](x)
        
        # decoder state input for the next time step
        decoder_state_input = decoder_states

    ##### ????? ????? ????? ????? ????? ????? ????? ????? ????? ?????
    # where do we evaluate stop condition?

    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model([self.details['encoder_inputs'], decoder_inputs], decoder_outputs)
    self.model = model

  def compile_and_fit(self,data_dict,params) :

    # compiling the model
    self.model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

     # printing the summary of the model   
    summary = self.model.summary()

    # plotting the model figure
    plot = plot_model(self.model, show_shapes=True)
    
    # total training samples
    train_samples = len(data_dict['train']['df'])

    # total validation samples 
    val_samples = len(data_dict['val']['df'])

    # batch size   
    batch_size = params['batch_size']

    # number of epochs
    num_epochs = params['num_epochs_2']

    # training the model
    run_details = self.model.fit_generator(generator = data_dict['train']['batch_greedy'],
                                            steps_per_epoch = train_samples//batch_size,
                                            epochs=num_epochs,
                                            callbacks=[
                                                      wandb.keras.WandbCallback()
                                                      ],
                                            validation_data = data_dict['val']['batch_greedy'],
                                            validation_steps = val_samples//batch_size)
   
    return {
        'run_details' : run_details
    }

  def evaluate(self, data_dict) :

    # test batch generator
    test_gen = data_dict['val']['batch_greedy']
    
    # number of test samples
    test_samples = len(data_dict['val']['df'])
  
    batch_size=32

    num_hits = 0
    
    for _ in range(test_samples//batch_size) :
      (a,b),c = next(test_gen)
      l1 = data_dict['tokenizer'].decode(np.argmax(c, axis=2), mode='output')
      out = self.model.predict([a,b])
      out = np.argmax(out,axis=2) 
      l2 = data_dict['tokenizer'].decode(out, mode='output')
      num_hits += np.sum(np.array(l1)==np.array(l2))
      print(l1, l2)

    print("Final Val Acc ", num_hits/test_samples)
    # wandb.log({"final_val_acc":  num_hits/test_samples})

# %%
# def evaluate(net, data_dict) :

#   # test batch generator
#   test_gen = data_dict['val']['batch_greedy']
  
#   # number of test samples
#   test_samples = len(data_dict['val']['df'])

#   batch_size=32

#   num_hits = 0
  
#   for _ in range(test_samples//batch_size) :
#     (a,b),c = next(test_gen)
#     l1 = data_dict['tokenizer'].decode(np.argmax(c, axis=2), mode='output')
#     out = net.model.predict([a,b])
#     out = np.argmax(out,axis=2) 
#     l2 = data_dict['tokenizer'].decode(out, mode='output')
#     # print(l1[1], l2[1])
#     num_hits += np.sum(np.array(l1)==np.array(l2))
#     # break

#   print("Val Acc ", num_hits/test_samples)
#   wandb.log({"final_val_acc":  num_hits/test_samples})

# %%
class tools:
  def init_params(config,data_dict):
  
    # returning parameters
    params = {
        'num_encode_layers' : config.num_encode_layers,
        'num_decode_layers' : config.num_decode_layers,
        'cell_type' : config.cell_type,
        'rep_size' : config.rep_size,
        'embed_size' : config.embed_size,
        'dropout' : config.dropout,
        'num_epochs' : config.num_epochs,
        'num_epochs_2' : config.num_epochs_2,
        'data_dict' : data_dict,
        'batch_size' : config.batch_size
    }
    return params

# %%
# sweep configuration
sweep_config = {
    'method' : 'bayes',
    'metric' : {
        'name' : 'val_acc',
        'goal' : 'maximize'
    },
    'parameters': {
        'cell_type' : {
            'values': ['LSTM', 'GRU', 'SimpleRNN']  
        },
        'embed_size': {
            'values': [10]
        },
        'rep_size': {
            'values': [32, 64, 128, 256]
        },
        'dropout': {
            'values': [0, 0.2, 0.4]
        },
        'batch_size': {
            'values': [32]
        },
        'num_epochs': {
            'values': [25]
        },
        'num_epochs_2' : {
            'values': [25]
        },
        'num_encode_layers': {
            'values': [1, 2, 4]
        },
        'num_decode_layers': {
            'values': [1, 2, 4]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project='dakshina_v2')
# Out:
# Create sweep with ID: 8cmmue87
# Sweep URL: https://wandb.ai/ramkamal/dakshina_v2/sweeps/8cmmue87

# %%
class sweep_module:
  @staticmethod
  def train(config=None):

    with wandb.init(config):
      
      # copying the config 
      config = wandb.config
 
      # naming the run
      # wandb.run.name = 'fil:'+str(config['num_filters_'])+'_type:'+config['type_of_filters'][0]+'_aug:'+str(config['augmentation'])[0]+'_dro:'+str(config['dropout'])[0]
      wandb.run.name = 'typ:'+config['cell_type'][:4]+ '_' + 'emb:'+str(config['embed_size'])+ '_' + 'enc:' + str(config['num_encode_layers'])+ '_' + 'dec:'+str(config['num_decode_layers'])
      
      # returning the data dictionairy
      data_dict = dict_data_dict[config.batch_size]

      # copying the parameters
      params = tools.init_params(config,data_dict)

      # creating and training the first model
      network = rnn(params)
      run_details = network.compile_and_fit(data_dict, params)

      # creating and training/ fine-tuning the second model
      rnn_2 = rnn_second(network.details)
      run_details_2 = rnn_2.compile_and_fit(data_dict,params)
      
      rnn_2.evaluate(data_dict)

# %%
# sweep_id = '7g0porer'

# %%
# performing the sweep
# wandb.agent(sweep_id, sweep_module.train)

# %% [markdown]
# # Best Model

# %%
params = {
    'num_encode_layers' : 2,
    'num_decode_layers' : 2,
    'cell_type' : 'LSTM', 
    'rep_size' : 256,
    'embed_size' : 10,
    'dropout' : 0,
    'num_epochs' : 5,
    'num_epochs_2' : 1,
    'data_dict' : data_dict,
    'batch_size' : 32
}

# %%
wandb.init()
network = rnn(params)
plot_model(network.model, show_shapes=True)
network.compile_and_fit(data_dict, params)
rnn_2 = rnn_second(network.details)
run_details_2 = rnn_2.compile_and_fit(data_dict, params)
rnn_2.evaluate(data_dict)
# Out:
# Finishing last run (ID:geixme2x) before initializing another...
# <br/>Waiting for W&B process to finish, PID 5056<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210513_151307-geixme2x/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210513_151307-geixme2x/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# </table>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lyric-music-2</strong>: <a href="https://wandb.ai/ramkamal/uncategorized/runs/geixme2x" target="_blank">https://wandb.ai/ramkamal/uncategorized/runs/geixme2x</a><br/>
# ...Successfully finished last run (ID:geixme2x). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">comic-leaf-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ramkamal/uncategorized" target="_blank">https://wandb.ai/ramkamal/uncategorized</a><br/>
#                 Run page: <a href="https://wandb.ai/ramkamal/uncategorized/runs/28w3oaec" target="_blank">https://wandb.ai/ramkamal/uncategorized/runs/28w3oaec</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210513_151518-28w3oaec</code><br/><br/>
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 10)     300         input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, None, 256)    273408      embedding_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 10)     500         input_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 256), (None, 525312      lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, None, 256),  273408      embedding_3[0][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 256),  525312      lstm_6[0][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 50)     12850       lstm_7[0][0]
# ==================================================================================================
# Total params: 1,611,090
# Trainable params: 1,611,090
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/5
# 2056/2056 [==============================] - 65s 26ms/step - loss: 0.7628 - acc: 0.3796 - val_loss: 0.3010 - val_acc: 0.7436
# Epoch 2/5
# 2056/2056 [==============================] - 49s 24ms/step - loss: 0.2239 - acc: 0.8237 - val_loss: 0.1612 - val_acc: 0.8687
# Epoch 3/5
# 2056/2056 [==============================] - 49s 24ms/step - loss: 0.1041 - acc: 0.9213 - val_loss: 0.1453 - val_acc: 0.8828
# Epoch 4/5
# 2056/2056 [==============================] - 49s 24ms/step - loss: 0.0659 - acc: 0.9509 - val_loss: 0.1398 - val_acc: 0.8910
# Epoch 5/5
# 2056/2056 [==============================] - 49s 24ms/step - loss: 0.0449 - acc: 0.9667 - val_loss: 0.1437 - val_acc: 0.8917
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 10)     300         input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, None, 256)    273408      embedding_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 10)     500         input_4[0][0]
#                                                                  tf.math.argmax[0][0]
#                                                                  tf.math.argmax_1[0][0]
#                                                                  tf.math.argmax_2[0][0]
#                                                                  tf.math.argmax_3[0][0]
#                                                                  tf.math.argmax_4[0][0]
#                                                                  tf.math.argmax_5[0][0]
#                                                                  tf.math.argmax_6[0][0]
#                                                                  tf.math.argmax_7[0][0]
#                                                                  tf.math.argmax_8[0][0]
#                                                                  tf.math.argmax_9[0][0]
#                                                                  tf.math.argmax_10[0][0]
#                                                                  tf.math.argmax_11[0][0]
#                                                                  tf.math.argmax_12[0][0]
#                                                                  tf.math.argmax_13[0][0]
#                                                                  tf.math.argmax_14[0][0]
#                                                                  tf.math.argmax_15[0][0]
#                                                                  tf.math.argmax_16[0][0]
#                                                                  tf.math.argmax_17[0][0]
#                                                                  tf.math.argmax_18[0][0]
#                                                                  tf.math.argmax_19[0][0]
#                                                                  tf.math.argmax_20[0][0]
#                                                                  tf.math.argmax_21[0][0]
#                                                                  tf.math.argmax_22[0][0]
#                                                                  tf.math.argmax_23[0][0]
#                                                                  tf.math.argmax_24[0][0]
#                                                                  tf.math.argmax_25[0][0]
#                                                                  tf.math.argmax_26[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 256), (None, 525312      lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, None, 256),  273408      embedding_3[1][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
#                                                                  embedding_3[2][0]
#                                                                  lstm_7[1][1]
#                                                                  lstm_7[1][2]
#                                                                  embedding_3[3][0]
#                                                                  lstm_7[2][1]
#                                                                  lstm_7[2][2]
#                                                                  embedding_3[4][0]
#                                                                  lstm_7[3][1]
#                                                                  lstm_7[3][2]
#                                                                  embedding_3[5][0]
#                                                                  lstm_7[4][1]
#                                                                  lstm_7[4][2]
#                                                                  embedding_3[6][0]
#                                                                  lstm_7[5][1]
#                                                                  lstm_7[5][2]
#                                                                  embedding_3[7][0]
#                                                                  lstm_7[6][1]
#                                                                  lstm_7[6][2]
#                                                                  embedding_3[8][0]
#                                                                  lstm_7[7][1]
#                                                                  lstm_7[7][2]
#                                                                  embedding_3[9][0]
#                                                                  lstm_7[8][1]
#                                                                  lstm_7[8][2]
#                                                                  embedding_3[10][0]
#                                                                  lstm_7[9][1]
#                                                                  lstm_7[9][2]
#                                                                  embedding_3[11][0]
#                                                                  lstm_7[10][1]
#                                                                  lstm_7[10][2]
#                                                                  embedding_3[12][0]
#                                                                  lstm_7[11][1]
#                                                                  lstm_7[11][2]
#                                                                  embedding_3[13][0]
#                                                                  lstm_7[12][1]
#                                                                  lstm_7[12][2]
#                                                                  embedding_3[14][0]
#                                                                  lstm_7[13][1]
#                                                                  lstm_7[13][2]
#                                                                  embedding_3[15][0]
#                                                                  lstm_7[14][1]
#                                                                  lstm_7[14][2]
#                                                                  embedding_3[16][0]
#                                                                  lstm_7[15][1]
#                                                                  lstm_7[15][2]
#                                                                  embedding_3[17][0]
#                                                                  lstm_7[16][1]
#                                                                  lstm_7[16][2]
#                                                                  embedding_3[18][0]
#                                                                  lstm_7[17][1]
#                                                                  lstm_7[17][2]
#                                                                  embedding_3[19][0]
#                                                                  lstm_7[18][1]
#                                                                  lstm_7[18][2]
#                                                                  embedding_3[20][0]
#                                                                  lstm_7[19][1]
#                                                                  lstm_7[19][2]
#                                                                  embedding_3[21][0]
#                                                                  lstm_7[20][1]
#                                                                  lstm_7[20][2]
#                                                                  embedding_3[22][0]
#                                                                  lstm_7[21][1]
#                                                                  lstm_7[21][2]
#                                                                  embedding_3[23][0]
#                                                                  lstm_7[22][1]
#                                                                  lstm_7[22][2]
#                                                                  embedding_3[24][0]
#                                                                  lstm_7[23][1]
#                                                                  lstm_7[23][2]
#                                                                  embedding_3[25][0]
#                                                                  lstm_7[24][1]
#                                                                  lstm_7[24][2]
#                                                                  embedding_3[26][0]
#                                                                  lstm_7[25][1]
#                                                                  lstm_7[25][2]
#                                                                  embedding_3[27][0]
#                                                                  lstm_7[26][1]
#                                                                  lstm_7[26][2]
#                                                                  embedding_3[28][0]
#                                                                  lstm_7[27][1]
#                                                                  lstm_7[27][2]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 256),  525312      lstm_6[1][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
#                                                                  lstm_6[2][0]
#                                                                  lstm_7[1][1]
#                                                                  lstm_7[1][2]
#                                                                  lstm_6[3][0]
#                                                                  lstm_7[2][1]
#                                                                  lstm_7[2][2]
#                                                                  lstm_6[4][0]
#                                                                  lstm_7[3][1]
#                                                                  lstm_7[3][2]
#                                                                  lstm_6[5][0]
#                                                                  lstm_7[4][1]
#                                                                  lstm_7[4][2]
#                                                                  lstm_6[6][0]
#                                                                  lstm_7[5][1]
#                                                                  lstm_7[5][2]
#                                                                  lstm_6[7][0]
#                                                                  lstm_7[6][1]
#                                                                  lstm_7[6][2]
#                                                                  lstm_6[8][0]
#                                                                  lstm_7[7][1]
#                                                                  lstm_7[7][2]
#                                                                  lstm_6[9][0]
#                                                                  lstm_7[8][1]
#                                                                  lstm_7[8][2]
#                                                                  lstm_6[10][0]
#                                                                  lstm_7[9][1]
#                                                                  lstm_7[9][2]
#                                                                  lstm_6[11][0]
#                                                                  lstm_7[10][1]
#                                                                  lstm_7[10][2]
#                                                                  lstm_6[12][0]
#                                                                  lstm_7[11][1]
#                                                                  lstm_7[11][2]
#                                                                  lstm_6[13][0]
#                                                                  lstm_7[12][1]
#                                                                  lstm_7[12][2]
#                                                                  lstm_6[14][0]
#                                                                  lstm_7[13][1]
#                                                                  lstm_7[13][2]
#                                                                  lstm_6[15][0]
#                                                                  lstm_7[14][1]
#                                                                  lstm_7[14][2]
#                                                                  lstm_6[16][0]
#                                                                  lstm_7[15][1]
#                                                                  lstm_7[15][2]
#                                                                  lstm_6[17][0]
#                                                                  lstm_7[16][1]
#                                                                  lstm_7[16][2]
#                                                                  lstm_6[18][0]
#                                                                  lstm_7[17][1]
#                                                                  lstm_7[17][2]
#                                                                  lstm_6[19][0]
#                                                                  lstm_7[18][1]
#                                                                  lstm_7[18][2]
#                                                                  lstm_6[20][0]
#                                                                  lstm_7[19][1]
#                                                                  lstm_7[19][2]
#                                                                  lstm_6[21][0]
#                                                                  lstm_7[20][1]
#                                                                  lstm_7[20][2]
#                                                                  lstm_6[22][0]
#                                                                  lstm_7[21][1]
#                                                                  lstm_7[21][2]
#                                                                  lstm_6[23][0]
#                                                                  lstm_7[22][1]
#                                                                  lstm_7[22][2]
#                                                                  lstm_6[24][0]
#                                                                  lstm_7[23][1]
#                                                                  lstm_7[23][2]
#                                                                  lstm_6[25][0]
#                                                                  lstm_7[24][1]
#                                                                  lstm_7[24][2]
#                                                                  lstm_6[26][0]
#                                                                  lstm_7[25][1]
#                                                                  lstm_7[25][2]
#                                                                  lstm_6[27][0]
#                                                                  lstm_7[26][1]
#                                                                  lstm_7[26][2]
#                                                                  lstm_6[28][0]
#                                                                  lstm_7[27][1]
#                                                                  lstm_7[27][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 50)     12850       lstm_7[1][0]
#                                                                  lstm_7[2][0]
#                                                                  lstm_7[3][0]
#                                                                  lstm_7[4][0]
#                                                                  lstm_7[5][0]
#                                                                  lstm_7[6][0]
#                                                                  lstm_7[7][0]
#                                                                  lstm_7[8][0]
#                                                                  lstm_7[9][0]
#                                                                  lstm_7[10][0]
#                                                                  lstm_7[11][0]
#                                                                  lstm_7[12][0]
#                                                                  lstm_7[13][0]
#                                                                  lstm_7[14][0]
#                                                                  lstm_7[15][0]
#                                                                  lstm_7[16][0]
#                                                                  lstm_7[17][0]
#                                                                  lstm_7[18][0]
#                                                                  lstm_7[19][0]
#                                                                  lstm_7[20][0]
#                                                                  lstm_7[21][0]
#                                                                  lstm_7[22][0]
#                                                                  lstm_7[23][0]
#                                                                  lstm_7[24][0]
#                                                                  lstm_7[25][0]
#                                                                  lstm_7[26][0]
#                                                                  lstm_7[27][0]
#                                                                  lstm_7[28][0]
# __________________________________________________________________________________________________
# tf.math.argmax (TFOpLambda)     (None, None)         0           dense_1[1][0]
# __________________________________________________________________________________________________
# tf.math.argmax_1 (TFOpLambda)   (None, None)         0           dense_1[2][0]
# __________________________________________________________________________________________________
# tf.math.argmax_2 (TFOpLambda)   (None, None)         0           dense_1[3][0]
# __________________________________________________________________________________________________
# tf.math.argmax_3 (TFOpLambda)   (None, None)         0           dense_1[4][0]
# __________________________________________________________________________________________________
# tf.math.argmax_4 (TFOpLambda)   (None, None)         0           dense_1[5][0]
# __________________________________________________________________________________________________
# tf.math.argmax_5 (TFOpLambda)   (None, None)         0           dense_1[6][0]
# __________________________________________________________________________________________________
# tf.math.argmax_6 (TFOpLambda)   (None, None)         0           dense_1[7][0]
# __________________________________________________________________________________________________
# tf.math.argmax_7 (TFOpLambda)   (None, None)         0           dense_1[8][0]
# __________________________________________________________________________________________________
# tf.math.argmax_8 (TFOpLambda)   (None, None)         0           dense_1[9][0]
# __________________________________________________________________________________________________
# tf.math.argmax_9 (TFOpLambda)   (None, None)         0           dense_1[10][0]
# __________________________________________________________________________________________________
# tf.math.argmax_10 (TFOpLambda)  (None, None)         0           dense_1[11][0]
# __________________________________________________________________________________________________
# tf.math.argmax_11 (TFOpLambda)  (None, None)         0           dense_1[12][0]
# __________________________________________________________________________________________________
# tf.math.argmax_12 (TFOpLambda)  (None, None)         0           dense_1[13][0]
# __________________________________________________________________________________________________
# tf.math.argmax_13 (TFOpLambda)  (None, None)         0           dense_1[14][0]
# __________________________________________________________________________________________________
# tf.math.argmax_14 (TFOpLambda)  (None, None)         0           dense_1[15][0]
# __________________________________________________________________________________________________
# tf.math.argmax_15 (TFOpLambda)  (None, None)         0           dense_1[16][0]
# __________________________________________________________________________________________________
# tf.math.argmax_16 (TFOpLambda)  (None, None)         0           dense_1[17][0]
# __________________________________________________________________________________________________
# tf.math.argmax_17 (TFOpLambda)  (None, None)         0           dense_1[18][0]
# __________________________________________________________________________________________________
# tf.math.argmax_18 (TFOpLambda)  (None, None)         0           dense_1[19][0]
# __________________________________________________________________________________________________
# tf.math.argmax_19 (TFOpLambda)  (None, None)         0           dense_1[20][0]
# __________________________________________________________________________________________________
# tf.math.argmax_20 (TFOpLambda)  (None, None)         0           dense_1[21][0]
# __________________________________________________________________________________________________
# tf.math.argmax_21 (TFOpLambda)  (None, None)         0           dense_1[22][0]
# __________________________________________________________________________________________________
# tf.math.argmax_22 (TFOpLambda)  (None, None)         0           dense_1[23][0]
# __________________________________________________________________________________________________
# tf.math.argmax_23 (TFOpLambda)  (None, None)         0           dense_1[24][0]
# __________________________________________________________________________________________________
# tf.math.argmax_24 (TFOpLambda)  (None, None)         0           dense_1[25][0]
# __________________________________________________________________________________________________
# tf.math.argmax_25 (TFOpLambda)  (None, None)         0           dense_1[26][0]
# __________________________________________________________________________________________________
# tf.math.argmax_26 (TFOpLambda)  (None, None)         0           dense_1[27][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, 50)     0           dense_1[1][0]
#                                                                  dense_1[2][0]
#                                                                  dense_1[3][0]
#                                                                  dense_1[4][0]
#                                                                  dense_1[5][0]
#                                                                  dense_1[6][0]
#                                                                  dense_1[7][0]
#                                                                  dense_1[8][0]
#                                                                  dense_1[9][0]
#                                                                  dense_1[10][0]
#                                                                  dense_1[11][0]
#                                                                  dense_1[12][0]
#                                                                  dense_1[13][0]
#                                                                  dense_1[14][0]
#                                                                  dense_1[15][0]
#                                                                  dense_1[16][0]
#                                                                  dense_1[17][0]
#                                                                  dense_1[18][0]
#                                                                  dense_1[19][0]
#                                                                  dense_1[20][0]
#                                                                  dense_1[21][0]
#                                                                  dense_1[22][0]
#                                                                  dense_1[23][0]
#                                                                  dense_1[24][0]
#                                                                  dense_1[25][0]
#                                                                  dense_1[26][0]
#                                                                  dense_1[27][0]
#                                                                  dense_1[28][0]
# ==================================================================================================
# Total params: 1,611,090
# Trainable params: 1,611,090
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2056/2056 [==============================] - 682s 250ms/step - loss: 0.3437 - acc: 0.2564 - val_loss: 0.2613 - val_acc: 0.2594
# ['டித்தால்', 'ிசைக்கு', 'ூலகமாக', 'ாகனத்தின்', 'ப்பெண்', 'ாங்கோ', 'ுவாம்', 'ய்வுச்', 'ொழுது', 'ெபர்சன்', 'ோகா', 'ந்தச்', 'ாலன்', 'லோசனையை', 'லைச்சொற்களை', 'ில்லி', 'ூறவே', 'ுனே', 'ண்களில்', 'ாத்திருந்து', 'ென்னாசிய', 'டைபெறும்போது', 'ோலி', 'ாரணமாக', 'ொழுதுபோக்குக்கு', 'ோற்றுவிக்கப்படும்', 'ுன்மாதிரியாக', 'ோல்', 'ருகிய', 'ிகழ்வுகளுக்கு', 'ரிசா', 'ாலி'] ['டித்தால்', 'ிசைக்கு்்', 'ூலமாகக', 'ாகந்ததின்', 'ப்பேன்', 'ாங்கோ', 'ோமா', 'ய்வுவ்', 'ோக்க', 'ெப்பர்ஸ்்', 'ூகாாா', 'ந்தாச்', 'ாலன்', 'லோசனையை', 'லிச்சுர்களை', 'ிலிி்', 'ுரவே', 'ுனிி', 'ண்களில்', 'ாத்திருந்து', 'ேனசிய', 'டைபெறும்பாது', 'ாலிி்', 'ாரணமாக', 'ொழுதுபோப்குக்்', 'ோற்றுவிக்கப்படம்', 'ுன்மூடியிரக', 'ோல்்', 'ருகியய', 'ிகழுவுகளுக்கு', 'ரிசாாாா', 'ாலிி']
# ['ோக்காக', 'ொஸ்', 'ெர்பிய', 'த்திரைப்படம்', 'ுருதிச்', 'ிர்ஸா', 'ன்மைகளும்', 'ங்கத்திலிருந்து', 'ாரிசன்', 'ிரை', 'ப்', 'தரவளித்த', 'ண்டர்', 'ூதாட்டத்தில்', 'ோழர்களால்', 'வுடர்', 'ற்றவர்களுக்கு', 'ட்', 'மிழ்நாடு', 'ெற்கே', 'ழித்தல்', 'டைத்துள்ளது', 'தியை', 'ுத்தப்', 'ொள்கிறார்', 'ிடைக்கும்போது', 'லயச்', 'ெபியன்', 'ீப்பற்றி', 'வதாரம்', 'ங்கங்களும்', 'ேர்ந்தெடுக்கப்பட'] ['ோக்காக', 'ாஸ்்்்்்்்்்்்', 'ேர்பியிய', 'த்திரப்படம்', 'ுருத்சிச்', 'ிர்சாாா', 'ன்மைகளும்', 'ங்கத்திரிருந்து', 'ரிசன்', 'ிறை', 'பப்', 'தரவலத்ததத', 'ுந்தர்', 'ூதாடாத்டிில்', 'ொழற்களால்', 'ாட்டர்', 'ற்றவர்களுக்கு', 'ேட்்்்்', 'மிழ்நாடு', 'ேர்கிி', 'ழித்தல்', 'டைத்துள்ளது', 'த்தைய', 'ுத்தப்', 'ொள்கிறார்்', 'ிடைக்கொண்போது', 'ழாயச்', 'ீபியான்', 'ீப்பரிி', 'தாதராம்', 'ங்கங்களும்', 'ேர்ந்தெடுக்கப்படட']
# ['திரடித்', 'காய', 'ிகழ்வுகளிலும்', 'ப்', 'லர்களின்', 'ெடிக்கும்போது', 'ாடங்கள்', 'லைச்சுவடிகள்', 'வ்', 'ேத்ரா', 'மெரிக்காவிலுள்ள', 'ூயிஸ்', 'டவுள்கள்', 'ீசஸ்', 'னோ', 'ரிசா', 'ரக்கு', 'ற்றி', 'லிவாக', 'ண்', 'ருத்துக்களுக்கு', 'ிடந்து', 'டமாகவும்', 'ுரிந்து', 'ெயலாற்றி', 'ுனைவதாக', 'ங்கி', 'ளம்', 'ெப்பத்தை', 'ந்தம்', 'ியாவ்', 'ீவிரவாதி'] ['திரடித்த', 'காயா', 'ிகழுவுகளிலும்', 'பப்', 'லர்களின்', 'ெடிக்கொம்போது', 'ாடங்கள்', 'லைசுவதிகளள்', 'ோ்', 'ேட்ர', 'மெரிக்வாருருு', 'ாயூஸ்்்', 'டவுக்கள்', 'ேசாஸ்்்்்்்்்்', 'ாண்', 'ரிசி', 'ற்கோ', 'ற்றிி', 'லிவாக', 'ுழந்தைை', 'ருத்துகளுக்குகுு', 'ிடந்து', 'டமாகவும்', 'ொள்லாாும்', 'ெயலாற்றிி', 'ுனைவதாக', 'ங்கி', 'ெங்களுடன்', 'ெப்பத்தை', 'ந்தம்', 'ையா', 'ீவிரவாதி']
# ['ீசன்', 'ருவாகாமல்', 'ங்கதேசத்தில்', 'ிஞ்ஞானிகள்', 'ம்சங்கள்', 'ருத்தாக்கங்கள்', 'ோட்டியை', 'டிகளில்', 'ற்படின்', 'லிங்கா', 'கடுகள்', 'வுடர்', 'ூட்டத்திற்கு', 'சேர்', 'ர்ணனை', 'ூட்டினை', 'ம்சங்களை', 'ென்னா', 'ரிமாற்ற', 'னுபல்லவி', 'ாண்கின்றனர்', 'ம்பால்', 'ுறைந்ததாக', 'ுடிகளுடன்', 'ாகுல்', 'ாதவர்', 'ுன்னணியும்', 'டிது', 'ிருவரங்கத்தில்', 'ாப்பாற்றி', 'ியமிக்கப்படும்', 'ண்டனைக்கு'] ['ினான', 'ருவாகளாம்', 'ங்கதேதத்தில்', 'ிண்ணானிகள்', 'ஞ்சசங்க', 'ருத்தாங்கள்கள்', 'ோட்டியைை', 'டிகளில்', 'ற்பட்ினன', 'ாிணாா', 'கடுகள்்', 'ாட்டர்', 'ூட்டத்திற்குு', 'ஸ்்', 'ர்னனன', 'ூட்டினைை', 'ஞ்சேங்களை', 'ென்னாா', 'ரிமாற்ற', 'னுபலலவேேே', 'ாங்கின்றனர்', 'ம்பல்', 'ுறைந்ததாக', 'ுடிகளுடன்', 'ாஜுல்', 'ாதவர்', 'ுன்னேியயு்', 'டித்து', 'ிருவரந்்கிிில்', 'ாப்பாற்றிி', 'ியமிக்கப்படுட்', 'ண்டனைக்கு']
# ['ரும்', 'ிந்தா', 'ேட்டி', 'ேமி', 'ுகுந்த', 'டற்கரைச்', 'ற்றவர்களுக்கும்', 'ான்', 'ோண்டப்பட்ட', 'ந்தியா', 'ருண்', 'லுவாக', 'மிழறிஞர்கள்', 'யதிலேயே', 'ூர்வாரி', 'திகப்படியான', 'ாறாகத்', 'ரியன்னை', 'ோசலிசம்', 'ெலுத்தி', 'ங்கிலியில்', 'ண', 'ியாகராஜரின்', 'ாஸ்கோ', 'ுகம்', 'ோலே', 'ிரந்த', 'ர்ரே', 'ிவப்பிரகாசர்', 'ுன்னரே', 'ோட்டிகளிலும்', 'ிர்வாகத்தைப்'] ['ரும்', 'ிந்தாா', 'ாட்ி', 'ாமிி', 'ுகுந்த', 'டற்கரைச்', 'ற்றவர்களுக்கும்', 'ன்', 'ொண்டப்பட்ட', 'ந்திய', 'ிஜய', 'லுவாக', 'மிழரின்கினாள்', 'யதிலேயே', 'ோர்வாறி', 'திகப்படியாய', 'ாராகத்', 'ரியன்்ை', 'ோசியாலின்', 'ெலுத்தி்', 'ங்கிழியில்', 'ீன்', 'ியாரராரரின்', 'ோசோரோோ', 'ுகம்', 'ாலிிி', 'ிராந்த', 'ுரேே', 'ிவப்பிரசாரரர்', 'ுன்னரே', 'ோட்டிகளிலும்', 'ிருவாக்்தை்்']
# ['சூதி', 'ற்றினால்', '்ரூமன்', 'ோல்கொண்டா', 'ிவில்', 'ின்னஸ்', 'ருக', 'டி', 'ித்திரைத்', 'ரிமாற்றம்', 'ய்வுகளும்', 'ெடு', 'ாஹூ', 'ீரேற்று', 'ரலாற்றுடன்', 'ங்கீகார', 'ெலவிடப்படும்', 'ுமிழிகள்', '', 'ழைப்புகள்', 'ல்லூரிகளில்', 'ீனா', 'வ்வோர்', 'லர்களின்', 'ல்லூரியை', 'ோபித்துக்கொண்டு', 'ான்', 'ின்புறமுள்ள', 'ுழுநேர', 'ரிமாற்றங்களை', 'ாவல்துறையில்', 'னோ'] ['சோடிிி', 'ற்றினால்', 'ிரமமனன', 'ொள்க்ந்டா', 'ிவில்்', 'ின்்்', 'ருகா', 'தம்', 'ித்திரைத்', 'ரிமாற்றம்', 'ய்வுகளும்', 'ேட்டு', 'ாகூோ்்்்்்்', 'ீரேற்றுு', 'ரலாட்டுடன்', 'ங்கேகேர', 'ெலவிடப்படும்', 'ுயிழிகள்்', 'ா்', 'ழைப்புகள்', 'ள்ளிகிகளில்', 'ேனாா', 'வ்வூர்்', 'லர்களின்', 'ள்்ோரியைய', 'ொட்ப்தொணொகொக்ுு', 'ென்', 'ின்புரமுள்ள', 'ுழுனி', 'ரிமாட்டங்களை', 'ாவல்துறையில்்', 'னனோ']
# ['வுடர்', 'ப்பசி', 'ள்ளடக்கத்தை', 'ேர்த்துப்', 'ுகாரி', 'ுடிக்கும்', 'ுத்திகரிக்கப்பட்ட', 'ந்த்', 'ொல்வார்', 'ிவி', 'ாணி', 'றிமுகம', 'தன்', 'ுனே', 'ந்தியாவும்', 'ிஞ்ஜா', 'தனில்', 'ொகை', 'ொல்வர்', 'ேர்த்துத்', 'ஸ்ட்ரோ', 'ாலன்', 'ுதுச்சேரியின்', 'ார்பன்', 'ெட்டிய', 'ாகனமான', 'ெறுத்து', 'ுளங்களுக்கு', 'ேலைகள்', 'ோகம்', 'ாயுமானவர்', 'ோசலிசப்'] ['ாட்டர்', 'ப்பாச்', 'ள்ளடக்கத்தை', 'ேர்த்துப்்', 'ுகாரிி', 'ோத', 'ுத்திகரிக்கப்பட்ட', 'ாந்த', 'ொல்வார்', 'ேவிி', 'ானி', 'ரிமுக', 'த்தன்', 'ூன', 'ந்தியாவும்்', 'ிஞ்சாா', 'தனிில்', 'ொகை', 'ால்வர்', 'ேர்த்துத்', 'ஸ்தரரோ', 'ாலன்', 'ுதுசிசி', 'ர்பான்', 'ட்டியயய', 'ாகணமான', 'ெருத்து்', 'ுலங்களுக்கு', 'ேளைகள்', 'ோகா்', 'ாயுமானரர்', 'ோசசிகப்']
# ['டங்களாக', 'ர்ப்பணித்து', 'ண்ணோட்டத்துடன்', 'ாதைகள்', 'ாதவ்', 'ுகழ்பெற்றவர்', 'ேலைக்கு', 'ம்சார', 'றிய', 'ுன்புறுத்தும்', 'ாபூல்', 'ரத்தை', 'ுறைமையில்', 'ரையாடல்கள்', 'ுசேலர்', 'ருள்', 'ுவியில்', 'றங்கும்', 'ண்டறிந்தவர்', 'ற்பிக்கப்', 'டுத்திக்', 'ுனே', 'ிபூதி', 'ங்கதேச', 'ுத்தம்', 'ாவங்களை', 'ுவக்கப்', 'ாங்கப்பட்ட', 'ந்தா', 'ாடங்கள்', 'ர்ப்புச்', 'ன்னல்களை'] ['டங்களாக', 'ர்ப்பந்த்து', 'ண்ணாட்டுத்தத்', 'ாதைகள்', 'ாடடவ', 'ுகற்கற்றவரரர', 'ேளைக்கு்்', 'ம்சார', 'ுடியாத', 'ுன்புறுத்தும்', 'ாப்லு்', 'ரத்தைை', 'ுறைமையில்்', 'ரையாடலளகள்', 'ுசல்ளர்', 'ருல்்', 'ுவியில்்', 'ரங்கும்', 'ண்டறிந்தவர்', 'டுபிகுுு', 'டுத்திக்்', 'ுனே', 'ிபோதிி', 'ங்கதேச', 'ுத்தம்', 'ாவங்களை', 'ுவக்கப்', 'ாங்கப்பட்ட', 'ந்தா', 'ாடங்கள்', 'ர்ப்பு்்்்்்்்்', 'ந்நில்களை']
# ['வைகளின்', 'மையப்', 'ல்வியாக', 'ுச்', 'ுதுவை', 'ர்வத்தையும்', 'ுகாரி', 'யிரின', 'ாவல்துறை', 'ுதலுதவி', 'ாங்கப்பட்ட', 'ுடிக்கும்', 'தவீதத்தை', 'லட்சம்', 'டைச்', 'ான்சன்', 'ர்வத்துடன்', 'ாலையையும்', 'ற்றினார்', 'ெருமிதம்', 'ழக்கும்', 'ூட்டத்தில்', 'ருக்கக்கூடிய', 'ெபியன்', 'டந்தை', 'ள்ளடக்கங்களை', 'ுயன்ற', 'ர்வாதிகாரத்தை', 'ெய்யப்பட்டுள்ள', 'ாஜன்', 'கோடா', 'ிமரிசையாக'] ['வைகளின்', 'ெற்றுள்ளது', 'ல்வியாக', 'ிய்்', 'ுதுவை்', 'ர்வத்தையும்', 'ுக்ரி', 'யிரினா', 'ாவல்துறை', 'ுதலுதவவி', 'ாங்கப்பட்ட', 'ோத', 'தவததத்தை', 'லட்சம்', 'டைச்', 'ானனன்', 'ர்வதுதுடன்', 'ாைையையும்்', 'ற்றினார்்', 'ெருமிதம்', 'ழக்கும்', 'ூட்டத்தில்', 'ருக்கக்கூடியி', 'பபனன்', 'டந்தைை', 'ள்ளடங்கங்களை', 'ுயன்ற', 'ர்வாரிக்ததததை', 'ெய்யப்பட்டுள்ள', 'ாஜன்', 'ாகோட', 'ிமரிசியாக']
# ['ங்கினர்', 'ோலே', 'ோட்டித்', 'ங்கேரி', 'ய்வுகளில்', 'ருங்கிணைப்பை', 'லந்தாய்வு', 'ர்ரே', 'தனில்', 'யிர்களையும்', 'ரசிம்மர்', 'ுவாசிக்கத்', 'ெபியன்', 'ூரி', 'ாற்றிலிருந்து', 'ப்பானுக்கு', 'ப்கானிய', 'ொடுதல்', 'ுனிதா', 'ாண்பித்து', 'ித்திரையில்', 'ிளையாடுவது', 'டைப்பட்டு', 'ராய்ந்தார்', 'ால்ட்', 'ல்லூரிகளில்', 'தழாளர்', 'ொழிலும்', 'சிரம', 'ாவல்துறை', 'கோடா', 'ண்பாடுகள்'] ['ங்கினர்', 'ாலிி', 'ேர்வில்', 'ுங்கரிி', 'ய்வுகளில்', 'ருங்கிணைப்பைை', 'லந்தாயுவு', 'ூரே', 'தனிில்', 'யிற்களையும்', 'ரச்சியர்', 'ுவசிக்தத்', 'ேபின்்்்்்', 'ூரிி', 'ாட்றிலிருந்து', 'ப்பானுக்கு்', 'ப்கானியாாாா', 'ொடுத்தல்', 'ுன்வி', 'ான்பித்துு', 'ித்தியிலி்', 'ிளையாடுவது', 'டைப்பட்டு', 'ராய்ந்தார்', 'ோல்ட்்', 'ள்ளோரிகளில்', 'தழாளர்', 'ொழிலும்', 'சிரமா', 'ாத்துரைை', 'கோாாாாா', 'ண்பாடுகள்']
# ['ெளியாகி', 'ிடைக்காமல்', 'ங்கீகார', 'ொழிலும்', 'ாரணத்தைப்', 'ங்கினார்', 'ோட்டிக்கு', 'றியவும்', 'ரக்கு', 'ெலவிட', 'ால்ட்', 'ப்பந்தங்களில்', 'ட்டுமானத்தில்', 'தர்', 'ுற்றுலாவின்', 'சேர்', 'களாய்', 'ூயி', 'ருவாகியுள்ளதாக', 'ர்மாவில்', 'ோகம்', 'ென்ஸ்', 'ய்வுகளிலும்', 'ற்ற', 'ார்களை', 'மிழகத்தில்', 'ுஜங்கள்', 'ேவாலயத்தின்', 'ுழைந்து', 'வலைகள்', 'லைக்', 'ூழப்பட்டு'] ['ெளியாகி', 'ிடைக்காளல்', 'ங்கீகேர', 'ொழிலும்', 'ாரணத்தைப்்', 'ங்கினார்', 'ோட்டிக்குு', 'ரியாவும்', 'ார்க்', 'ெலவிடட', 'ால்', 'ப்பந்தங்களில்', 'ட்டுமானததில்', 'தத்', 'ுற்றுவாவின்்', 'ஸர்', 'களாய்', 'ூய்்', 'ருவாகியிளுள்ள', 'ூரமமவிில்', 'ோகா்', 'ெஸ்்்்்', 'ய்வுகளிலும்', 'ற்ற', 'ார்களை', 'மிழாாத்திி்', 'ுஜங்கள்', 'ேவாளத்திதின்', 'ுலைந்து்', 'வலைகள்', 'ோவன்', 'ூழப்பட்டு']
# ['ாணிக்கக்', 'லவற்றிலும்', 'ுலவர்களுக்கு', 'ற்றும்', 'டிகளை', 'ிடைக்கும்போது', 'ோற்றுவிக்கப்பட்ட', 'ம்மோனியம்', 'ெரியோர்', 'டகமாக', 'ூஜ்யம்', 'சிப்பதில்', 'ூன்றாவது', 'வியரசு', 'ர்வலரும்', 'ற்படத்', 'திலே', 'ிகழ்த்துவது', 'ோ', 'னரக', 'னக்கே', 'ின்புறம்', 'பசார', 'மச்சீரான', 'ப்பானியர்கள்', 'ருண்', 'மிழறிஞர்கள்', 'ற்றி', 'ப்பிரிக்கா', 'ிடயங்கள்', 'டன்பாடு', 'ின்னஸ்'] ['ானிக்கக்', 'லவற்றிலும்', 'ுலவர்களுக்கு', 'ற்றும்்', 'டிகளை', 'ிடைக்கொண்போதுு', 'ோற்றுவிக்கப்பட்ட', 'மனனனியும்', 'ெரியூர்்', 'டகமாக', 'ூசியம்', 'சீச்பிதிில', 'ூன்றாவது', 'வியரரு', 'ர்வரரவும்', 'ற்படத்', 'திலே', 'ிகழ்த்துவது', 'ோஸ்்்்்்்்்்', 'ணராக', 'னக்கே', 'ின்புரம்', 'பாசா', 'மச்சேயான', 'ப்பானியர்கள்', 'ருஜன்', 'மிழரின்கினாள்', 'ற்றிி', 'பிரிக்', 'ிடாஙங்கள்', 'டன்பாடு', 'ின்னி']
# ['ாலி', 'ேர்ந்தெடுக்கப்படும்', 'ாஸ்கோவில்', 'யில்', 'ாண்கின்றனர்', 'ெளியாகின', 'ிடும்', 'ைதிகளையும்', 'ாம்', 'டலைப்', 'டிப்பைப்', 'ட்டைக்கு', 'ார்பன்', 'ுணாதிசயங்களை', 'சன்', 'மிழகத்தில்', 'ற்றவர்களுடன்', 'ிறனால்', 'ிரம்மத்தின்', 'ூனைகளை', 'ிருவடிகளை', 'ிறந்த', 'ளுந்து', 'ேட்டதை', 'ைதிகளுடன்', 'டி', 'ுறைந்தாலும்', 'ோன்றது', 'ிர்ஸா', 'ழைய', 'ியாபாரிகள்', 'ெற்றியில்'] ['லிி', 'ேர்ந்தெடுக்கப்படும்', 'ாசூரில்்்', 'ாயி', 'ாங்கின்றனர்', 'ெளியாகின', 'ிடுமு', 'ைதிகளியும்', 'ாம்ி்்', 'டலைப்', 'டிப்பைப்்்', 'ட்டைக்கு்', 'ர்பான்', 'ுணத்சசைகளகளை', 'ச்ன்', 'மிழகத்தில்', 'ற்றவர்களுடன்', 'ிரனால்', 'ிரமாத்தின்', 'ூணைகளை', 'ிருவாகத்கள', 'ிராண்ட்', 'ள்ளுது', 'ேடத்தை', 'ைதிகளுடன்', 'திி', 'ுறைந்தாலும்', 'ோன்றது', 'ிர்சாாா', 'ழைய', 'ியாபாரிகள்', 'ெட்றியில்்']
# ...
# ['லாநிதி', 'ரிமாற்றத்தின்', 'ாகன', 'ுழலில்', 'க்கும்', 'ங்கி', 'ாக்', 'ிரைகளில்', 'ீப்பற்றிக்', 'டைந்த', 'ுயேச்சை', 'ோட்டியைத்', 'ோலே', 'பசார', 'ெலுத்தினார்', 'ேட்டி', 'ரசிம்மர்', 'ூடுகள்', 'ோட்', 'ோகத்', 'ப்பந்தங்கள்', 'ரக்கட்டை', 'ட்', 'றங்கும்', 'திர்பார்ப்புகளை', 'ந்திரமாக', 'ூட்டினால்', 'ெயல்படவும்', 'ெயலாற்றுவது', 'ொரித்த', 'மெரிக்காவிலும்', 'மைத்துப்'] ['ாலந்தி', 'ரிமாட்டத்தின்', 'ாகனா', 'ுழலில்', 'க்கும்', 'ங்கிி', 'ாக்்்்்்்ீள்ள்', 'ிரைகளில்', 'ீப்பர்றிக்', 'டைந்த', 'ுயிசை', 'ோட்டையைத்்', 'ாலிி', 'பாசா', 'ெலுத்தினார்்', 'ட்டியி', 'ரச்மி்்்', 'ூடுடககள்', 'ோட்', 'ோகாத்', 'ப்பந்தங்களளல்', 'றக்கட்டை', 'ுட்்', 'றங்கும்', 'திர்பார்புக்களை', 'ந்திரமாக', 'ூட்டினால்', 'ெயல்படுவவு', 'ெயலாற்றுவது', 'ோரித்த', 'மெரிக்வாவிவும்', 'மைத்துப்்்']
# ['ிளையாடுவதற்கு', 'ின்', 'ம்பதிகளின்', 'ேட்டி', 'ாங்', 'ாட்டை', 'ிம்', 'ோலி', 'ாதையாக', 'மயத்தவர்', 'ூட்டுவதற்கு', 'ம்ப்', 'றுதுணையாக', 'டி', 'டையற்ற', 'டற்கொள்ளையர்கள்', 'ிமிடெட்', 'ணவுப்பொருட்கள்', 'ாதவ்', 'லைக்', 'ிமானங்களை', 'ழங்கப்பட', 'ுளங்களுக்கு', 'டையானது', 'ுரியும்', 'ெண்ணுடன்', 'றிய', 'ருத்துவமனையில்', 'ுல்லட்', 'ேகரிப்பில்', 'ர்ரே', 'ெய்யப்பட்டன'] ['ிளையாடுவதுககு', 'ின்', 'ம்பதிகளின்', 'ட்டிி', 'ங்்', 'ட்டைை', 'ிம்்்்்்்்', 'ால்ி', 'ாதையாக', 'மயத்தாரர்', 'ூட்டுவதற்கு', 'ம்ப', 'றுதுதையாக', 'டிடிி', 'டையறறறற', 'டற்கொளொரைக்கள்', 'ிமிட்ட்', 'ணவுப்புு்்்்்்', 'ோட்', 'லைக்', 'ிமானங்களை', 'ழங்கப்படட', 'ுலங்களுக்கு', 'டையானது', 'ுரியும்்', 'ென்னுடன்', 'ரிய', 'ருத்துவதங்கயில்', 'ிலாட்', 'ேகரிப்பில்்', 'ூர்றே', 'ெய்யப்பட்டன']
# ['ருத்தால்', 'கந்தது', 'ப்போதெல்லாம்', 'ொகையும்', 'ோட்டிகளுக்கான', 'ூயஸ்', 'ருநூறுக்கும்', 'ிமிடெட்', 'ீட்டிற்கு', 'ேட்டல்', 'ேருந்தில்', 'ல்லவர்', 'ீரோ', 'ழைப்புகளை', 'ிரசுரங்களை', 'ம்மோனியம்', 'ிரிவாகவும்', 'ேவாலயங்களில்', 'னந்த்', 'தரிக்க', 'லக்ட்ரான்', 'ொடர்பானவை', 'ில்லி', 'ார்க்கண்டேய', 'ள்ளடக்கங்கள்', 'லைவருக்கு', 'ழக்குகளின்', 'சன்', 'ாண்டவர்களின்', 'ரும', 'ணங்களின்', 'ழியில்லை'] ['ருத்தால்', 'கந்தது', 'ப்போதலாலால்', 'ொகையும்', 'ோட்டிகளுக்கான', 'ுயில்்்்்்்்்்', 'ருநுருக்கும்்', 'ெமிடடட்', 'ீட்டிற்குு', 'ேட்டல்', 'ேர்ந்தில்', 'ள்ளவர்', 'ெரோோோ்்்்்', 'ழைப்புகளைை', 'ிரச்சுங்களை', 'மோனாயிய்', 'ிரிவகவுு்', 'ேவாளமங்களில்', 'னந்த', 'தரிக்க', 'லிக்றார்்', 'ொடர்பாணவை', 'ிலிி்', 'ார்க்்டியய', 'ள்ளடங்கள்கள்', 'லைவருக்கு', 'ழக்குகளின்', 'ானன', 'ாண்டவர்களின்', 'ருமா', 'ணங்களின்', 'ழியில்லை']
# ['ார்களை', 'ருத்துக்களும்', 'ூற', 'ோட்டியிலிருந்து', 'சுக்களை', 'ுத்த', 'ராய்ந்தனர்', 'ீவிரவாதிகளால்', 'ெண்மணிகள்', 'த்வைத', 'ொற்பொழிவுகளை', 'ண்பாடுகள்', 'ிர்வாகத்தை', 'ாப', 'ியோல்', 'ெய்யப்பட்டவர்', 'ண்டான', 'ீன்களை', 'லிங்கா', 'ிர்வாகம்', 'சைக்கருவிகளின்', 'ிவனது', 'ுஷ்கர்', 'காராஜன்', 'னத்தவர்களின்', 'ன்மாவை', 'ீலாத்', 'ிகழ்வுக்குப்', 'ொடந்து', 'னில்', 'ொடர்புகளை', 'ீச்'] ['ார்களை', 'ருத்துகளும்', 'ொட', 'ோட்டியிலிருந்து', 'சுக்களை', 'ுத்த', 'ராண்ந்தனர்', 'ீவிரவிகாகளால்', 'ென்ணமிகள்', 'டிவதத', 'ொற்போலிவுகளை', 'ண்பாடுகள்', 'ிர்வாகத்தை', 'ாபா', 'ியோல்்்்்்்', 'ெய்யப்பட்டவர்', 'ண்டான', 'ீங்களை', 'ாலின', 'ிர்வாகம்', 'சைக்குுவ்ிிிின்', 'ிவனதத', 'ுஸ்கார', 'காராஜன்', 'னத்தவர்களின்', 'ன்மாவை', 'ீலாத்்்்்்்்்்', 'ிகழுவுக்கு்', 'ொடங்துு', 'ணில்்', 'ொடர்புகளைை', 'ெய்்்்்்்்்']
# ['வதாரமான', 'ாடங்கள்', 'ாக்', 'ீர்வாக', 'ோண்டப்பட்ட', 'ாதனங்கள்', 'ிஞ்ஞானிகளுக்கு', 'ருப்புத்', 'ிசேஷ', 'ிடயத்தையும்', 'ூட்டில்', 'ிறந்தான்', 'ூழப்பட்ட', 'ீரா', 'ுஷ்கர்', 'லவி', 'ெயல்படுவதற்கு', 'றப்பை', 'ேவாலயங்களில்', 'ல்வியையும்', 'ூட்டத்துடன்', 'ிளிம்புகளில்', 'ிடைக்கும்போது', 'ொள்வதாக', 'ுறைந்ததால்', 'ீரிய', 'ரவல்லது', 'ாலந்தா', 'ியாபாரி', 'ோகங்களை', 'ூதாட்ட', 'ற்றுக்கொண்ட'] ['தாதரமனன', 'ாடங்கள்', 'ாக்', 'ீர்வாக', 'ொண்டபபபடட', 'ாதனங்கள்', 'ிஞ்லாலிகளகக்கு', 'ருப்புத்', 'ிசேச', 'ிதைத்தையயும்', 'ூட்டில்்', 'ிரந்தான்', 'ோழப்பட்ட', 'ிர்ா', 'ுச்கர்', 'லவி', 'ெயல்படுவதற்கு', 'றப்பைை', 'ேவாளங்களிலி்', 'ல்வியையும்்', 'ூடடடட்டட்', 'ிள்மிப்புகளி்', 'ிடைப்பொழ்போது', 'ொள்வதாக', 'ுறைந்ததால்', 'ீரிய', 'ரவல்்து', 'ாளந்தா', 'ியாபாரி', 'யகங்களை', 'ூராடாட்', 'ற்றுக்கொண்ட']
# ['ிருபாகரன்', 'வரிடமே', 'ிருமுழுக்குப்', 'ாறாகக்', 'ருப்புப்', 'ராய்ந்த', 'ட்டமைக்கும்', 'ுகுமாரன்', 'ூட்டினை', 'ாதகமாக', 'ோகத்தை', 'ாதாரணமானது', 'ூட்டினார்', 'ஸ்தோக்', 'ோயிங்', 'ொதி', 'ீல்', 'லக்கணத்தில்', 'ேட்ட', 'ொதி', 'ுரிந்து', 'ீர்மானித்தது', 'ூடுகள்', 'தனம்', 'மேகா', 'ாசா', 'ீனா', 'ம்மோனியம்', 'ற்றவர்களைப்', 'ட்புறத்தில்', 'ூக்', 'ாகனத்திலிருந்து'] ['ிருப்காரன்', 'வரிடமே', 'ிருமுழுக்குப்', 'ாராகக்', 'ருப்புப்்்்்்', 'ராய்ந்த', 'ட்டமைக்கும்', 'ுகுமரான்', 'ுவிட்டினை', 'ாதகமாக', 'ோகத்தைை', 'ாதாரணமானது', 'ூட்டினார்்', 'ஸ்டோட்்்்்்்்்்்', 'ோயிங்்்்்்்்்்்', 'ோதிி', 'ீளி்்்்்', 'லக்கனத்தில்', 'ேட்ட', 'ோதிி', 'ொள்ளா', 'ீர்மானிதததது', 'ூடுகள்', 'தனம்', 'ஜியாாாாா்்', 'ாசாா', 'ேன', 'மோனியும்', 'ற்றவர்களைப்', 'ட்புதத்தில்', 'ாக்்்்்்', 'ாகந்திிரிரநந்தது']
# ['ருத்தால்', 'ோன்றியதாக', 'டி', 'யானா', 'ூட்டில்', 'ிரம்மத்தின்', 'ாவல்துறையை', 'னதா', 'ெல்லி', 'ணியையும்', 'ப்', 'யிரினத்தை', 'ிறைக்', 'ிட்யூட்டரி', 'ித்தியாசாலை', 'ேலூர்', 'வற்றுள்', 'ோதி', 'ிகழ்வுக்குப்', 'டங்களுக்கு', 'ாரிஸ்', 'ாகுல்', 'ேடான்', 'ோகா', 'ாற்றுக்', 'ஷ்ய', 'வுர்ணமி', 'ேகலை', 'ுறவியாக', 'ணியாக', 'டல்நல', 'லிகார்'] ['ருத்தால்', 'ோன்றியாாக', 'ட்டிி', 'ாணா', 'ுவிட்டில்்', 'ிரம்மத்தின்', 'ாவல்துறையை', 'னாடாாா', 'ேலிி', 'ணியையும்்', 'ப்', 'யிரிநந்தை', 'ுட்டம்', 'ிடிடுட்ரி', 'ிதிதாயைய', 'ேலூர்்', 'வற்றுள்்்', 'ோதிிி', 'ிகழுவுக்கு்', 'டங்களுக்கு', 'ேசிஸ்்்்', 'ாஜுவ்', 'ீடன்', 'ோகாாா', 'ாற்றுக்்', 'ஷியிா', 'வுரமணி', 'ேகலை', 'ுறவியாக', 'ணியாக', 'டல்நா', 'லிகாஸ்']
# ['ுறைமையின்', 'னஅழுத்தம்', 'வுண்டி', 'ப்பிரிக்கா', 'திப்பித்தார்', 'ீசும்', 'ப்படத்தின்', 'ாலக்', 'ங்கத்தால்', 'டன்', 'ோகச்', 'ணிகளில்', 'ிம்', 'ருக்கவே', 'ளவயது', 'ூலகமாக', 'ுத்தருக்கு', '்வீட்', 'ால்ட்', 'ாசிக்', 'ிசைகள்', 'ுத்த', 'ேரத்', 'ூர்', 'ொறுப்பேற்றார்', 'னந்த்', 'ழங்கப்படும்', 'டந்தார்', 'தவீதத்தை', 'ீழ்ச்சிக்கு', 'ுவங்கப்பட்டு', 'ர்ப்பாட்டத்தில்'] ['ுறைமையின்', 'னாழுத்தம்', 'வூண்டிி', 'ப்ரிக்காாா', 'திப்பித்தார்', 'ீசும்', 'ப்படத்தின்', 'ட்டத்தைை', 'ங்கத்தால்', 'தின்்', 'ோகாஷ்', 'ணிகளில்', 'ீம்்', 'ருக்கவே', 'ளவையது', 'ூலமாகக', 'ுத்தருக்கு', 'ுவீத்', 'ால்', 'சிககக', 'ிசைகள்', 'ுத்த', 'ிராத்', 'ோர்்்்்்்்்்', 'ொருப்பேட்ரார்', 'னந்்்', 'ழங்கப்படும்', 'டந்தார்', 'தவதித்தை', 'ீச்சிச்கிகு', 'ுவங்கப்பட்டு', 'ர்பாடாட்்தில்']
# ['ென்னா', 'சல்', 'ள்ளீடுகளை', 'ிலத்து', 'ுகந்தன்', 'டைகள்', 'ெய்பவர்களை', 'ிரந்த', 'ுணாதிசயங்களை', 'ைதிகளுடன்', 'ிம்ப்சன்', 'ியாகராஜா', 'ற்றாமல்', 'ாம்', 'ஜய்', 'ெலுத்தி', 'ுஷ்கின்', 'ேலைகளிலும்', 'டங்களும்', 'ூறப்பட்டாலும்', 'லக்கணத்தை', 'ேக்கம்', 'ோலிருக்கும்', 'ிசைக்கு', 'ாத்திருந்தனர்', 'ீனிவாசன்', 'காலிங்கம்', 'ளவுக்கான', 'டுகள்', 'ளவுகளில்', 'ர்ரே', 'ீட்டிற்கு'] ['ேனாா', 'சல்', 'ள்ளெடுகளைை', 'ிலத்து', 'ுக்்ந்தன்', 'டைக்கள்', 'ெய்பவர்களை', 'ிரந்த', 'ுணத்தைைக்களை', 'ைதிகளுட்டன்', 'ிம்போன்ன்்்்்்்', 'ியாராாச', 'ற்்ாால்', 'ாம்்', 'ஜிி்', 'ெலுத்திி', 'ுஸ்கின்்்', 'ேலைகளிலும்', 'டங்களும்', 'ூறப்பட்டால்', 'லக்கணந்தை', 'ேக்கம்', 'ோலிருக்கும்', 'ிசைக்கு்்', 'ாத்திருந்தனர்', 'ீனிவானன்', 'களிங்கம்', 'ளவுக்கான', 'டுகள்்', 'ளவுகளில்', 'ுரை', 'ீட்டர்கு']
# ['ிசைகள்', 'ற்பட', 'ார்பன்', 'டிசன்', 'ிவான்', 'ஞ்சித்', 'ிடுதலைப்', 'ாலந்தா', 'ேவாலயத்தில்', 'டங்களில்', 'ருவாகும்போது', 'ார்களை', 'ோட்டிகள்', 'ம்சங்களின்', '்ரூமன்', 'ரியர்கள்', 'ரக்கு', 'டிவயிற்றை', 'ோட்பாடுகளைப்', 'யின்', 'ொடந்து', 'ிரம்மன்', 'வ்வோர்', 'ோன்றியதை', 'ாக்', 'ென்ஸ்', 'ட்புறத்தை', 'மெரிக்கர்களின்', 'ொழிலே', 'டுமையான', 'ோன்றியவர்', 'ிறன்களை'] ['ிசைகள்', 'ற்பட', 'ர்பன்', 'டிஷான்்்', 'ிவான்', 'ஞ்ச்சி', 'ோராட்டம்', 'ாளந்தா', 'வவலாயத்தி்', 'டங்களில்', 'ருவாக்ப்போது', 'ர்களை', 'ோட்டிகள்', 'ஞ்வாங்களின்', 'ிருமன்', 'ரியர்கள்', 'ற்கோோ', 'டிவேற்றை', 'ோட்பாட்டுகள்', 'ண்்', 'ொடங்து', 'ிராாமன்', 'வ்வரர்', 'ோன்றியதை', 'ார்்', 'ெஸ்்்்்்்்்்்', 'ட்புதக்தை', 'மெரிக்கரரகள்', 'ொழிலே', 'டுமையான', 'ோன்றியவர்', 'ிறங்களை']
# ['ெபர்சன்', 'ெய்ததன்', 'ொற்பொழிவு', 'ங்கி', 'ேம்பாலத்தை', 'டுத்தது', 'ிறந்ததை', 'ுஷ்கர்', 'ூற', 'ூறவே', 'ாலக்', 'ுலவர்களும்', 'ீல்', 'ரீனா', 'ுவிந்த', 'ோலி', 'லிங்க', 'மிழகத்திற்கு', 'ூறப்பட்டால்', 'ற்று', 'ாக்', 'ாற்றும்', 'ோர்ட்', 'ெயலாற்றும்', 'மிழகத்', 'ழக்குகள்', 'ாதகமான', 'ென்ஸ்', 'ாலத்தைப்', 'ண்ணோட்டத்தை', 'ியாபாரிகள்', 'டுத்தனர்'] ['ெப்பஸ்்்', 'ெய்ததன்', 'ொற்போலிவுு', 'ங்கி', 'ேம்பாளத்தை', 'டுத்ததுு', 'ிரந்ததை', 'ோஸ்கார்', 'ொட்ியமாா', 'ூரவே', 'ட்டங்கள்', 'ுலவர்களும்', 'ெயில்', 'ரின', 'ுவிந்த', 'ாலிி்', 'ாிங்க', 'மிழகத்திற்கு', 'ூறப்பட்டால்', 'ற்றற', 'ேக்', 'ாற்றும்்', 'ோர்ட்', 'ெயலாற்றும்', 'மிழகாத்', 'ழக்குகள்்', 'ாதகமான', 'ிஸ்்்்்', 'ாலத்தைப்்', 'ண்னோட்டாத', 'ியாபாரிகள்', 'டுத்தனர்']
# ['டனுதவி', 'ுமி', 'ங்கேரி', 'றியக்கூடிய', 'ூலகங்களை', 'ாவத்தைத்', 'ாலக்', 'ிலோ', 'ேளாங்கண்ணி', 'ரத்திலும்', 'னவியல்', 'டைசித்', 'ெர்மானிய', 'ணியில்', 'யன்ற', 'ர்ணனை', 'ளவுகளைக்', 'ார்', 'ாற்றுச்', 'ாழ்க', 'வலைகள்', 'சின்', 'தனம்', 'ய்வுகளும்', 'சேர்', 'ாஸ்தா', 'ிர்வகிக்கப்பட்டு', 'ாட்டுவதாகவும்', 'மெரிக்காவுடன்', 'ணிவதே', 'ொகைப்', 'னதா'] ['டதுத்தவ', 'ுமி', 'ங்காரிி', 'ரியக்கூடியிய', 'ோலங்கங்களை', 'ாவத்தைத்', 'ெட்வுக்க்க்', 'ிளோோோ', 'ேளாண்கங்கி', 'ராடிிுு்', 'னவியல்', 'டைசித்', 'ெர்மானிய', 'ணியில்', 'யந்ற', 'ர்னனை', 'ளவுகளைக்', 'ார்', 'ாற்றுச்', 'ாழ்க', 'வலிகள்', 'சின்', 'தனன்', 'ய்வுகளும்', 'சர்', 'ஷ்த்', 'ிருவகிக்கப்பட்டு', 'ாட்டுவதாகவும்', 'மெரிக்காடாவான்', 'ணிவதே', 'ொகைப்்', 'னாடாாாா']
# ['ெப்லர்', 'யிர்களையும்', 'காயம்', 'ந்துக்களும்', 'ீவிரவாதிகள்', 'டி', 'சீரா', 'னோ', 'ிகழ்வுகளில்', 'ுலவர்களால்', 'ாசனம்', 'ாதகமாக', 'ொகுப்பை', 'ாப்பா', 'ிடைக்கும்போது', 'ொழு', 'றங்கு', 'ருவாகியுள்ளது', 'ும்மி', 'ிரித்தது', 'ாதவர்கள்', 'ப்கானிய', 'ூறப்பட்டன', 'ொழிலும்', 'ம்ச', 'ழக்கறிஞரும்', 'ிருவரங்கன்', 'ணிநேரத்திற்கு', 'ரிந்துரைக்கும்', 'டிமத்தை', 'ேட்டல்', 'றியப்பட்டார்'] ['ாப்ளர்', 'யிற்களையும்', 'காயம்', 'ந்துக்களும்', 'ீவிரவிகககள்', 'டிி்', 'ெஜிகாாா', 'ானு', 'ிகழ்வுகளில்', 'ுலவர்களால்', 'சனன்', 'ாதகமாக', 'ொகுப்பை்', 'ாபா', 'ிடைப்பொம்போதுு', 'ொழ்ு', 'றங்கு', 'ருவாகியுள்ளது', 'ிம்ி', 'ிரித்ததுு', 'ாதவர்கள்', 'ப்காணியா', 'ூறப்பட்டன', 'ொழிலும்', 'மராாா', 'ழக்கரிர்ருும்', 'ிருவரங்கள்', 'னினீறத்த்றிற', 'ரிந்துரைக்கும்', 'டிமத்தை', 'ேட்டல்', 'ரியப்பட்டார்']
# ['டன்', 'ென்னா', 'ப்பிரிக்கா', 'ுன்மாதிரியாக', 'மிழகத்துடன்', 'ோயிங்', 'ீசும்', 'னுராதபுர', 'ரக்கு', 'ாக்', 'ோனன்', 'ற்ற', 'ுத்தருக்கு', 'ிருமூர்த்தி', 'லர்களால்', 'ேலைக்காக', 'டைத்ததாக', 'ோயிங்', 'ணவுக்கு', 'ென்னா', 'ீழ்ச்சியை', 'ாகனத்திலிருந்து', 'ீரிழிவு', 'ேதங்களையும்', 'ூதாட்டத்தில்', 'மிழகத்தில்', 'ெல்லி', 'லர்களை', 'ந்தைகள்', 'ெடிக்க', 'ிசைன்', 'சையாத'] ['தான்்்', 'ெனனனா', 'ப்கிராகா', 'ுன்மாதியிரக', 'மிழாகத்துதன்', 'ாம்ங்்்்்்்்்', 'ீசும்', 'னுராதப்ர', 'ற்கோோோ', 'ாக்', 'ோனன்', 'ா்்', 'ுத்தருக்கு', 'ிரும்ச்ிி', 'லர்களால்', 'ேளைக்காக', 'டைத்ததாக', 'ாய்ங்்்்்்்்்', 'ணவுக்கு்', 'ென்னா', 'ிசுச்சியை', 'ாகந்திிரிரநந்து', 'ீரிலுு', 'ேதங்களையும்', 'ூதாடத்ததில்', 'மிழகத்தில்', 'ேலிி', 'லர்களை', 'ந்திகள்', 'ெடிக்க', 'ிசிக்்்்்்்்', 'சையாத']
# ['ொடர்பான', 'டன்', 'மிட்டி', 'ரும்பலகை', 'ுடிகளை', 'ோட்பாடுகள்', 'டைத்த', 'த்தோ', 'ெஸ்', 'ோசலிசம்', 'ப்பந்தத்தை', 'ைவிங்', 'களாய்', 'ுறிப்பேடு', 'ுனேவில்', 'ாகனங்களை', 'ியாவ்', 'ோல்விகளையும்', 'ாதையிலிருந்து', 'ிஞ்ஞானிகளுக்கு', 'ிகழ்வுக்கு', 'ைகுண்டம்', 'ாதவ்', 'பூர்வ', 'ிமோர்', 'ருவாக்கக்கூடிய', 'ஞ்சித்', 'ரமாக', 'ுதைத்த', 'ேத்ரா', 'ம்பராமாயணம்', 'திகளில்'] ['ொடர்பன', 'யடன்', 'மிடடடிி', 'ரும்பகளை', 'ுடிகளை', 'ோட்பாட்டுகள்', 'டைத்த', 'த்தோ', 'ெஸ்்்்', 'ோசாலிமம்', 'ப்பந்தத்தை', 'ேவிங்்', 'களாய்', 'ுறிப்பாடுு', 'ுனவில்்', 'ாகஙங்களை', 'ையாது', 'ோழிவிகளையும்', 'ாதையிலிரநந்து', 'ிண்னியாலிகளுக்', 'ிகழ்வுக்கு', 'ேகுகுண்ட', 'ாதவவ', 'ப்தா்ா', 'ைமூர்்', 'ருவாக்காக்கதயி', 'ஞ்சிி்', 'ரமாக', 'ுதைத்த', 'ேத்ராா', 'ம்பரமாானம்', 'திகளில்']
# ['னப்பாடம்', 'ோட்டியைத்', 'ீனா', 'ேங்காய்', 'திர்கட்சியாக', 'ண்பாடுகளை', 'ல்லூரியும்', 'யானா', 'ிக்கனம்', 'பநிடதம்', 'ார்பற்ற', 'ெஸ்பிட்', 'னோ', 'ூட்டி', 'ரத்தையும்', 'ிபூதி', 'ொடர்பும்', 'ென்ஸ்', 'தினெண்', 'டங்கள்', 'மிழகத்தில்', 'ுணாதிசயங்கள்', 'ியா', 'றுதுணையாக', 'ிடந்தன', 'ெற்றிகரமாகத்', 'ன்றியும்', 'டைபெறும்', 'டத்தல்', 'ம்மோனியா', 'ஸ்தோக்', 'ிகழ்வுகளுடன்'] ['னப்பாடம்', 'ோட்டியைத்', 'ீனாா', 'ேங்காம்்', 'திர்க்சாசியக', 'ண்பாடுடுகள்', 'ள்ளிரியும்', 'ுயான', 'ிக்லா்', 'பனிடதம்', 'ார்பற்றர', 'ிர்பிப்', 'னனோ', 'ுட்டிி', 'ரதையைம்்்', 'ிபோதிிி', 'ொடர்பும்', 'ிஸ்்்்்', 'ீழ்ககண்ககக', 'டங்கள்', 'மிழகத்தில்', 'ுணாதச்சிகளள்', 'ியாா', 'றுதுதையாக', 'ிடந்தன', 'ெற்றிகராயகத்', 'ன்றியும்்', 'டைபெறும்', 'டத்தல்', 'ம்மோனியாா', 'ஸ்டோட்்்்்்்்்்்', 'ிகழுவுகளுடன்']
# ['ுளிர்ச்சியான', 'ேலைத்', 'ல்லூரிகள்', 'ாவரும்', 'ம்மோனியா', 'ர்டர்', 'ிலோ', 'ியர்', 'ாங்', 'ுருதியில்', 'னித்தன்மையை', 'ிடயங்களும்', 'லைவராவார்', 'ுன்புறுத்தலில்', 'ற்படின்', 'ந்திரம்', 'ிறந்தாலும்', 'ூர்ணா', 'ுகாரி', 'வித்த', 'மீஸ்', 'ோசனையின்', 'ிமுகவில்', 'ீசஸ்', 'லைவனின்', 'லந்துக்', 'ென்னி', 'ர்வாதிகாரத்தை', 'ூட்டங்களும்', 'ிட்ரிக்', 'ிஜேபி', 'ருத்துக்களால்'] ['ுளிர்ச்சியான', 'ிட்டங்களுக்கு', 'ள்ளிறிகள்', 'வரவும்', 'மனினி', 'ர்டர்', 'ிலோோு', 'ெர்்்்', 'னர்', 'ுருத்தியில்்', 'னித்மனையைை', 'ிதயங்களும்', 'லைவராவரர்', 'ுன்புற்த்துலல்', 'ற்பட்னி்', 'ர்திரம்', 'ிரந்தாலும்', 'ூர்ாாா', 'ுகரரி', 'வித்த', 'ேமீஸ்்', 'சானையின்', 'ில்கியில்்', 'ேசாஸ்்', 'லைவனின்', 'லந்துக்்்்்', 'ென்னிி', 'ர்வாரிக்தததை', 'ூட்டங்களும்', 'ிற்றிக்்', '்ப்்்்்்்', 'ருத்துகளளளால்']
# ['ர்வாதிகார', 'ுன்மாதிரியாக', 'ளம்பெண்களை', 'ணவும்', 'ூலகமாக', 'ெலுத்தின', 'ாழ்வோர்', 'ஷிஷ்', 'ாலக்', 'டுகளை', 'ுள்ளை', 'ியாவ்', 'னிம', 'மவாய்ப்பு', 'ஞ்சித்', 'ம்பி', 'ுத்திகரிக்கப்பட்ட', 'ிறந்தால்', 'ிழையான', 'ிஸினஸ்', 'ோனன்', 'ிராமணர்', 'கிழ்ச்சியையும்', 'வீனமான', 'மிழை', 'ரவுகளைச்', 'லயத்தை', 'மிழகத்தில்', 'ாயிலாகத்', 'கோடா', 'ருவாகுவதை', 'ாரின்'] ['ர்வாதியாக', 'ுன்மாதியியரா', 'ளன்பங்களுடன்', 'ணவும்', 'ூலமாகக', 'ெலுத்தின', 'ாழ்வூர்்', 'ஷிஸ்்்்்்்்்்', 'ட்டட்டைை', 'டுகளை', 'ுள்லை', 'ேயோ்்்', 'னிி', 'மவைப்புு', 'ஞ்சிி்', 'ாம்பி', 'ுத்திகரிக்கப்பட்ட', 'ிரந்தால்', 'ிளையான', 'ிசினா', 'ோனன்', 'ிராமணர்', 'கிழ்சியோயைம்்', 'வினமானன', 'மிிை', 'ரவுகளைச்', 'ழையத்தை', 'மிழகாத்தில்', 'ாயிலாகத்', 'கக்வா', 'ருவாகுவதை', 'ாரின்']
# ['ூதுவர்', 'ூக்', 'யானா', 'ண்ணிம', 'ஸ்தோக்', 'க்கி', 'ுற்றுலாவை', 'ோயின', 'னம்', 'ீப்பற்றிக்', 'ம்சங்கள்', 'ர்வ', 'திகமானோர்', 'ேற்று', 'ந்நிறுவனத்தில்', 'ாகனமான', 'ாக்', 'ாதுவை', 'மமாகவே', 'ரத்தையும்', 'ாதவ்', 'ண்டி', 'ிறவும்', 'யுட்', 'ிகழ்வுகளும்', 'ோட்டியாளர்களை', 'ுரோணரின்', 'ருபடி', 'ோற்றுவித்த', 'ின்வாங்கி', 'ேதம்', 'ார்பற்ற'] ['ூத்துவர்', 'ாக்்', 'ுயான', 'ண்ணெம', 'ாஸ்டுக்்', 'ாக்கிி', 'ுற்றுவாவை', 'ோயின', 'னம்', 'ீப்பாற்றிக்', 'ச்சாங்கள்', 'ர்வ', 'திகாமாரர்', 'ிரகசாவாயா', 'ண்ணிருுநதததில்', 'ாகணமான', 'ாக்', 'ாதுவை', 'மமகாகி', 'ரத்தையும்்', 'டுவ', 'ண்டி', 'ிரவும்', 'யடட்', 'ிகழ்வுகளும்', 'ோட்டியாளர்களை', 'ுரானரின்', 'ருபாடிடிி', 'ோற்றுவித்த', 'ின்வாண்கி', 'ேதம்', 'ார்பாட்ட']
# ['ெல்லி', 'ுழுநேர', 'றிமுகம', 'ிடந்தான்', 'ன', 'டுங்கி', 'ூடு', 'ிறந்ததும்', 'கிழ்ச்சியை', 'ராய்ந்த', 'ாரிசன்', 'னாதை', 'டனுதவி', 'சூதி', 'ற்று', 'ணேஸ்', 'மைச்சு', 'ிகாரையில்', 'ூறப்பட்டது', 'ணிகர்', 'ாறாகக்', 'ருவாக்கும்போது', 'ாளிகை', 'ர்டர்', 'ரிசினை', 'ியாகராஜரின்', 'ிஞ்ஞானிகளுக்கு', 'ாரிசன்', 'ற்றவர்களால்', 'ல்லூரியிலிருந்து', 'டுங்கி', 'டிவான'] ['ேல்லி', 'ுழுனேற', 'ரிமுகம', 'ிடந்தான்', 'ான்்்்்்', 'டுங்கிி', 'ூட்டு', 'ிரந்ததும்', 'கிழ்சியியை', 'ராய்ந்த', 'ரரர்யன்', 'னாதைை்', 'டுநததவி', 'சுதிிி', 'த்று', 'ேன்', 'மைச்சு', 'ிகாரையில்', 'ூறப்பட்டது', 'ணிகர்', 'ாராகக்', 'ருவாக்குப்போது', 'ாலிகை', 'ர்டர்', 'ரிசினை', 'ியாரராரரின்', 'ிஞ்ஞாலிருகளுகு', 'ரிசன்', 'ற்றவர்களால்', 'ள்ளோரியிரிருந்து', 'டுங்கிி', 'டிவான']
# ['ாவங்களை', 'லக்ட்ரான்', 'ரங்களில்', 'ிடந்தார்', 'சிரமத்தை', 'சேர்', 'லிங்கா', 'ீங்களும்', 'ூநகரி', 'ங்கத்தால்', 'ொல்வார்', 'பநிடதம்', 'ளத்திலும்', 'ெளிப்புற', 'யிரினத்தின்', 'ிகழ்த்தப்பட்டு', 'ெய்யுளில்', 'சிப்பதில்', 'ங்கிலியின்', 'ெளிப்புறக்', 'ோன்றே', 'ோட்டியை', 'டங்கியிருக்கும்', 'ந்தியாவிலும்', 'ண்டனையாக', 'ைக்ரோ', 'மிழக', 'ர்மாவின்', 'ின்', 'ொட்டுக்', 'வைகள்', 'ப்பொழுதுதான்'] ['ாவங்களை', 'ழற்கான்்', 'ரங்களில்', 'ிட்்தார்', 'சிரமத்தை', 'சிர்', 'ள்்ி்்ாாாா', 'ீங்களும்', 'ூனரரி', 'ர்கத்தால்', 'ால்வார்', 'பனிடத்்்', 'ளத்திலும்', 'ெளிப்புற', 'யிரினத்தின்', 'ிகழ்த்தப்பட்டு', 'ெய்யிலில்்', 'சிப்பிிிி', 'ங்கிழியின்', 'ெளிப்புறர்', 'ோன்றே', 'ோட்டியை', 'டங்கியிருக்கும்', 'ந்தியாவிலும்்', 'ண்டனையாக', 'ைக்ோோ', 'மிழகக', 'ரர்மாின்', 'ின்', 'ொட்டுக்்்்்்்', 'வைகள்்', 'ப்புழுத்தாதனன']
# Final Val Acc  0.29751580185212406

# %%
evaluate(rnn_2, data_dict)

# %% [markdown]
# ## Test Function

# %%
def evaluate_test
