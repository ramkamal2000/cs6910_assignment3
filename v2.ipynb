# %% [markdown]
# # TO DO
# 1. Figure out dataset
# 2. Break down into individual characters
# 3. Form corpus from dataset for input and output characters
# 4. Assign a number to each character
# 5. Model will have an embedding so it will handle it
# 6. Output will be a bunch of integers so we will have to decode it

# %%
import tarfile
import os
import pandas as pd

# %%
# !wget -nc https://storage.googleapis.com/gresearch/dakshina/dakshina_dataset_v1.0.tar

if not os.path.isdir('/content/dakshina_dataset_v1.0'):
  tarfile.open("/content/dakshina_dataset_v1.0.tar").extractall()
# Out:
# --2021-04-23 03:15:25--  https://storage.googleapis.com/gresearch/dakshina/dakshina_dataset_v1.0.tar
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 173.194.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2008340480 (1.9G) [application/x-tar]
# Saving to: ‘dakshina_dataset_v1.0.tar’
#
# dakshina_dataset_v1 100%[===================>]   1.87G   130MB/s    in 12s
#
# 2021-04-23 03:15:37 (166 MB/s) - ‘dakshina_dataset_v1.0.tar’ saved [2008340480/2008340480]

# %% [markdown]
# # Loading Data

# %%
class data_loader():

  @staticmethod
  def load_devanagiri():
    lex = dict()
    lex['train'], lex['val'], lex['test'] = [], [], [] 
    column_names = ['input', 'output', 'count']

    languages = ['hi', 'mr']
    
    for la in languages:
      lex['train'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.train.tsv', sep='\t', header=None, names=column_names))
      lex['val'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.dev.tsv', sep='\t', header=None, names=column_names))
      lex['test'].append(pd.read_csv('/content/dakshina_dataset_v1.0/'+la+'/lexicons/'+la+'.translit.sampled.test.tsv', sep='\t', header=None, names=column_names))

    lex['train'] = pd.concat(lex['train'])
    lex['val'] = pd.concat(lex['val'])
    lex['test'] = pd.concat(lex['test'])

    return lex    

  @staticmethod
  def make_dataframe(lex):
    
    for div in ['train', 'val', 'test']:
    
      # removing non max transliterations
      idx = lex[div].groupby(['input'])['count'].transform(max) == lex[div]['count']
      lex[div] = lex[div][idx].reset_index(drop=True)

      # calclulating difference in lengths of various transliterations
      lex[div]['input_len'] = lex[div].apply(lambda x: len(str(x['input'])), axis=1)
      lex[div]['output_len'] = lex[div].apply(lambda y: len(str(y['output'])), axis=1)
      lex[div]['mod_dif'] = lex[div].apply(lambda z: abs(z['input_len'] - z['output_len']), axis=1) 

      # removing transliterations that vary by a lot in length
      idx = lex[div].groupby(['input'])['mod_dif'].transform(min) == lex[div]['mod_dif']
      lex[div] = lex[div][idx].reset_index(drop=True)

      # removing duplicates if any remain
      lex[div].drop_duplicates(subset='input', keep='first', inplace=True)

      # removing redundant columns
      lex[div].drop(labels=['count', 'input_len', 'output_len', 'mod_dif'], inplace=True, axis=1)

    return lex

# %%
lex = data_loader.load_devanagiri()
lex = data_loader.make_dataframe(lex)

# %%
df = lex['train']

# %%
df.input.tolist()

# %% [markdown]
# # Dataset Generation

# %%
class Tokenizer:

  def __init__(self, df):

    self.start_token = '<STR>'
    self.stop_token = '<STP>'
    self.unknown_token = '<UNK>'

    self.input_corpus = [self.start_token, self.stop_token, self.unknown_token]
    self.output_corpus = [self.start_token, self.stop_token, self.unknown_token]

    input_words = df.input.tolist()
    output_words = df.output.tolist()

    for word in input_words:
      tokens = str(word)
      for token in tokens:
        if token not in self.input_corpus:
          self.input_corpus.append(token)

    for word in output_words:
      tokens = str(word)
      for token in tokens:
        if token not in self.output_corpus:
          self.output_corpus.append(token)
    
    self.encode_dict_input = {self.input_corpus[i] : i+1 for i in range(len(self.input_corpus))}
    self.decode_dict_input = {k:v for v,k in self.encode_dict_input.items()}
    
    self.encode_dict_output = {self.output_corpus[i] : i+1 for i in range(len(self.output_corpus))}
    self.decode_dict_output = {k:v for v,k in self.encode_dict_output.items()}

  # takes in lists of words and returns lists of integers
  def encode(self, X, mode='input'):

    if (mode=='input'):
      input_list = []
      for word in X:
        word = str(word)
        integer_list = [self.encode_dict_input[self.start_token]] + [self.encode_dict_input.get(token, self.encode_dict_input[self.unknown_token]) for token in word] + [self.encode_dict_input[self.stop_token]]
        input_list.append(integer_list)
      
      return input_list
    
    if (mode=='output'):
      output_list = []
      for word in X:
        word = str(word)
        integer_list = [self.encode_dict_output[self.start_token]] + [self.encode_dict_output.get(token, self.encode_dict_output[self.unknown_token]) for token in word] + [self.encode_dict_output[self.stop_token]]
        output_list.append(integer_list)
      
      return output_list
    

  # takes in lists of integers and returns lists of words
  def decode(self, X, mode='input'):

    if (mode=='input'):
      input_list = []
      for integers in X:
        token_list = [self.decode_dict_input.get(integer, '0') for integer in integers[1:-2]] 
        input_list.append(''.join(token_list))
      
      return input_list

    if (mode=='output'):
      output_list = []
      for integers in X:
        token_list = [self.decode_dict_output.get(integer, '0') for integer in integers[1:-2]] 
        output_list.append(''.join(token_list))
      
      return output_list

# %%
tk = Tokenizer(df)

# %%
print(tk.encode_dict_input)
# Out:
# {'<STR>': 1, '<STP>': 2, '<UNK>': 3, 'अ': 4, 'ं': 5, 'क': 6, 'ग': 7, 'ण': 8, 'ि': 9, 'त': 10, 'ल': 11, 'ु': 12, 'र': 13, 'श': 14, 'न': 15, 'े': 16, 'भ': 17, '्': 18, 'ष': 19, 'ा': 20, 'ी': 21, 'ठ': 22, 'य': 23, 'ो': 24, 'ू': 25, 'ज': 26, 'च': 27, 'म': 28, 'ट': 29, 'ड': 30, 'व': 31, 'ः': 32, 'ह': 33, 'द': 34, 'प': 35, 'ृ': 36, 'स': 37, 'ध': 38, 'ै': 39, '़': 40, 'ब': 41, 'उ': 42, 'ॉ': 43, 'ई': 44, 'ख': 45, 'घ': 46, 'छ': 47, 'ञ': 48, 'फ': 49, 'ओ': 50, 'थ': 51, 'ढ': 52, 'झ': 53, 'ौ': 54, 'आ': 55, 'इ': 56, 'ँ': 57, 'ए': 58, 'ऊ': 59, 'ॅ': 60, 'ऋ': 61, 'ऑ': 62, 'ऐ': 63, 'औ': 64, 'ङ': 65, 'ॐ': 66, 'ळ': 67, 'ऱ': 68, '\u200d': 69, 'ऍ': 70, 'ॲ': 71}

# %%
X_train1 = tk.encode(df.input.tolist())
print(X_train1)
# Out:
# %%
X_train2 = tk.encode(df.output.to_list(),'output')

# %%
print(tk.decode_dict_output)
# Out:
# {1: '<STR>', 2: '<STP>', 3: '<UNK>', 4: 'a', 5: 'n', 6: 'k', 7: 'g', 8: 'i', 9: 't', 10: 'u', 11: 'c', 12: 'l', 13: 'e', 14: 'r', 15: 's', 16: 'h', 17: 'b', 18: 'y', 19: 'o', 20: 'j', 21: 'm', 22: 'd', 23: 'v', 24: 'w', 25: 'p', 26: 'z', 27: 'f', 28: 'x', 29: 'q'}

# %%
waw = tk.encode(df.output.tolist(), mode='output')
print(waw)
# Out:
# [[1, 4, 5, 2], [1, 4, 5, 6, 7, 4, 5, 8, 9, 2], [1, 10, 5, 11, 12, 13, 2], [1, 4, 5, 6, 10, 14, 2], [1, 4, 5, 6, 10, 14, 4, 5, 2], [1, 4, 5, 6, 10, 14, 8, 9, 2], [1, 4, 5, 6, 10, 15, 16, 2], [1, 4, 5, 7, 2], [1, 4, 5, 7, 4, 5, 13, 2], [1, 4, 5, 7, 17, 16, 4, 5, 7, 2], [1, 4, 5, 7, 14, 4, 6, 15, 16, 4, 6, 2], [1, 4, 5, 7, 4, 14, 4, 2], [1, 4, 5, 7, 4, 14, 13, 2], [1, 4, 5, 7, 8, 2], [1, 4, 5, 7, 8, 6, 4, 14, 2], [1, 4, 5, 7, 10, 9, 16, 13, 2], [1, 4, 5, 7, 10, 12, 2], [1, 4, 5, 7, 10, 12, 8, 18, 19, 5, 2], [1, 4, 5, 7, 10, 12, 8, 2], [1, 4, 5, 7, 10, 9, 16, 4, 2], [1, 4, 5, 7, 10, 9, 16, 8, 18, 19, 5, 2], [1, 4, 5, 7, 10, 9, 16, 8, 2], [1, 4, 5, 7, 10, 9, 16, 13, 2], [1, 4, 5, 7, 10, 14, 2], [1, 4, 5, 7, 10, 14, 8, 2], [1, 4, 5, 7, 10, 14, 19, 5, 2], [1, 4, 5, 7, 19, 5, 2], [1, 4, 5, 7, 19, 12, 4, 2], [1, 4, 5, 7, 14, 4, 20, 8, 2], [1, 4, 5, 7, 14, 13, 20, 8, 2], [1, 4, 5, 11, 16, 4, 12, 2], [1, 4, 5, 11, 16, 4, 12, 19, 5, 2], [1, 4, 5, 20, 4, 5, 2], [1, 4, 5, 20, 4, 5, 4, 2], [1, 4, 5, 20, 4, 4, 5, 2], [1, 4, 5, 20, 4, 5, 8, 2], [1, 4, 5, 20, 4, 5, 13, 2], [1, 4, 5, 20, 4, 14, 2], [1, 4, 5, 20, 13, 13, 14, 2], [1, 4, 5, 20, 10, 21, 2], [1, 4, 5, 20, 10, 21, 4, 5, 2], [1, 4, 5, 20, 10, 2], [1, 4, 5, 9, 4, 14, 11
'adhikarit', 'adhikariy', 'adhikariyo', 'adhikar', 'adhikariyo', 'adhikaro', 'adhikans', 'adhiga', 'adhigrahi', 'adhigraha', 'adhigrahano', 'adhigrahi', 'adhigrahi', 'adhina', 'adhinast', 'adhinayakwad', 'adhiniya', 'adhiniyamo', 'adhinirna', 'adhipat', 'adhipaty', 'adhibha', 'adhiy', 'adhirat', 'adhira', 'adhivakt', 'adhivas', 'adhivesha', 'adhishes', 'adhishtat', 'adhishtha', 'adhisuchn', 'adhisuchi', 'adhiksha', 'adhigraha', 'adhi', 'adhint', 'adhinst', 'adhi', 'adhirt', 'adhur', ' ...

# %%
X_val = tk.encode(lex['val'])

# %%
data = {}
data['train']['X'] = X_train1
data['train']['Y'] = X_train2
data['in_size'] = len(tk.input_corpus)
data['out_size'] = len(tk.output_corpus)

# %% [markdown]
# # Question 1

# %%
class rnn():

  def __init__(self, params):
    num_encode_layers = params['num_encode_layers']
    num_decode_layers = params['num_decode_layers']
    data = params['data']
    in_size = params['data']['in_size']
    out_size = params['data']['out_size']
    cell_type = params['cell_type']
    dropout = params['dropout']
    embed_size = params['embed_size']
    rep_size = params['rep_size']
    model = Sequential()
    model.add(layers.Embedding(input_dim=in_size, output_dim=embed_size))

    for j in range(num_encode_layers) :
      if cell_type == 'RNN' :
        model.add(layers.SimpleRNN(rep_size,dropout=dropout))
      elif cell_type == 'GRU' :
        model.add(layers.GRU(rep_size,dropout=dropout))
      elif cell_type == 'LSTM' :
        model.add(layers.LSTM(rep_size,dropout=dropout))

    for j in range(num_decode_layers) :
      if cell_type == 'RNN' :
        model.add(layers.SimpleRNN(rep_size,dropout=dropout))
      elif cell_type == 'GRU' :
        model.add(layers.GRU(rep_size,dropout=dropout))
      elif cell_type == 'LSTM' :
        model.add(layers.LSTM(rep_size,dropout=dropout))

    model.add(layers.Dense(out_size,activation='softmax'))
    self.model=model
    

  def compile_and_fit(self,data,params):
    train_ds, val_ds = data['train'], data['val']
    optimizer, epochs = params['optimizer'], params['num_epochs']
    if optimizer == 'NAG' :
      optimizer = tf.keras.optimizers.SGD(momentum=0.9,nesterov=True)
    self.model.compile(optimizer=optimizer, 
                       loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                       metrics=['accuracy']
                       )
    
    summary = self.model.summary()

    run_details = self.model.fit(train_ds, 
                                 validation_data=val_ds, 
                                 epochs=epochs,
                                 callbacks=[keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                                                          patience=3, 
                                                                          min_delta=0.0025)]
                                 )

    return {
        'run_details' : run_details
    }

# %%
df.output.tolist()
# Out:
# ['an',
#  'ankganit',
#  'uncle',
#  'ankur',
#  'ankuran',
#  'ankurit',
#  'ankush',
#  'ang',
#  'angane',
#  'angbhang',
#  'angrakshak',
#  'angara',
#  'angare',
#  'angi',
#  'angikar',
#  'anguthe',
#  'angul',
#  'anguliyon',
#  'anguli',
#  'angutha',
#  'anguthiyon',
#  'anguthi',
#  'anguthe',
#  'angur',
#  'anguri',
#  'anguron',
#  'angon',
#  'angola',
#  'angraji',
#  'angreji',
#  'anchal',
#  'anchalon',
#  'anjan',
#  'anjana',
#  'anjaan',
#  'anjani',
#  'anjane',
#  'anjar',
#  'anjeer',
#  'anjum',
#  'anjuman',
#  'anju',
#  'antarctica',
#  'antonio',
#  'antoni',
#  'andaman',
#  'undercover',
#  'undertaker',
#  'underworld',
#  'underwear',
#  'anda',
#  'andakar',
#  'andashay',
#  'andon',
#  'ant',
#  'antahkaran',
#  'anttogtva',
#  'antrgrahiy',
#  'antarmhadvipiye',
#  'antarrashtriya',
#  'antarrashtriya',
#  'antaratma',
#  'antral',
#  'antrashtriya',
#  'antriksh',
#  'antrikshyatri',
#  'antrikshyan',
#  'antrim',
#  'antaron',
#  'antargat',
#  'antardrishti',
#  'antardeshiy',
#  'antnirhit',
#  'antarman',
#  'antarrashtriy',
#  'antarvastr',
#  'antrvirodhon',
#  'antarvaiyaktik',
#  'antim',
#  'antule',
#  'antya',
#  'antyeshti',
#  'antyoday',
#  'andar',
#  'andruni',
#  'andaajan',
#  'andaaz',
#  'andaja',
#  'andeshaa',
#  'andhak',
#  'andhkar',
#  'andhkarpurn',
#  'andhta',
#  'andhvishvason',
#  'andhadhundh',
#  'andhe',
#  'andhepan',
#  'umpire',
#  'ambika',
#  'ambedkar',
#  'umbrella',
#  'antargat',
#  'antarrashtriya',
#  'ansh',
#  'anshkalik',
#  'anshat',
#  'anshdharkon',
#  'anshavatar',
#  'anshi',
#  'anshon',
#  'ansal',
#  'ansari',
#  'akbarpur',
#  'akbarabad',
#  'akarmanyata',
#  'aklera',
#  'akalpit',
#  'accounting',
#  'accountant',
#  'akaatya',
#  'akadamik',
#  'academy',
#  'akaar',
#  'akarbanic',
#  'akaal',
#  'akalmrityu',
#  'akali',
#  'akira',
#  'akushal',
#  'academy',
#  'akel',
#  'akela',
#  'akelapan',
#  'akeli',
#  'akele',
#  'akelepan',
#  'academy',
#  'akola',
#  'akkineni',
#  'akkineni',
#  'october',
#  'october',
#  'akriyashil',
#  'across',
#  'akl',
#  'aksh',
#  'akshat',
#  'aksham',
#  'akshamta',
#  'akshay',
#  'akshar',
#  'aksharsh',
#  'aksharon',
#  'akshansh',
#  'akshunn',
#  'aks',
#  'aksar',
#  'aksaee',
#  'akhandata',
#  'akhrot',
#  'akhbar',
#  'akhbaron',
#  'akhada',
#  'akhade',
#  'akhilesh',
#  'akhtar',
#  'akhtiyar',
#  'agam',
#  'agartala',
#  'agarbattiyon',
#  'agarbatti',
#  'agariya',
#  'agla',
#  'agali',
#  'agale',
#  'agava',
#  'augustus',
#  'agastya',
#  'agastyamuni',
#  'agaadh',
#  'agasi',
#  'aguvae',
#  'against',
#  'again',
#  'agnashay',
#  'agni',
#  'agnidev',
#  'agnimandya',
#  'agnisar',
#  'agnihotra',
#  'agnihotri',
#  'agnyashay',
#  'agragami',
#  'agraj',
#  'agrani',
#  'agradut',
#  'agrabhag',
#  'agrasar',
#  'agrasen',
#  'agrahari',
#  'agrahaye',
#  'agrim',
#  'agrenji',
#  'angrejon',
#  'agreshit',
#  'agroha',
#  'aghoriyon',
#  'achambhit',
#  'achala',
#  'achanak',
#  'achar',
#  'achin',
#  'achuk',
#  'achet',
#  'achetan',
#  'achcha',
#  'achhai',
#  'achchhe',
#  'achha',
#  'achhi',
#  'achut',
#  'achuta',
#  'achute',
#  'ajanta',
#  'ajgar',
#  'ajnabiyon',
#  'ajnabi',
#  'ajnaala',
#  'ajab',
#  'ajmat',
#  'ajamal',
#  'ajmer',
#  'ajmeri',
#  'ajay',
#  'ajayraj',
#  'ajarbejan',
#  'ajrada',
#  'ajva',
#  'azerbaijan',
#  'ajaan',
#  'aziz',
#  'ajatshatru',
#  'ajayabghar',
#  'aji',
#  'ajit',
#  'ajeeb',
#  'ajim',
#  'ajuba',
#  'ajubon',
#  'ajaivik',
#  'agyaatvas',
#  'agyaan',
#  'agnanta',
#  'agney',
#  'atkalen',
#  'atal',
#  'atlanta',
#  'atlantic',
#  'atut',
#  'attend',
#  'attendance',
#  'attack',
#  'atharahvin',
#  'atharah',
#  'atharahvin',
#  'adchanen',
#  'adi',
#  'adolf',
#  'adda',
#  'anima',
#  'anu',
#  'anuon',
#  'antarashtriya',
#  'ata',
#  'ati',
#  'atiutsah',
#  'atikraman',
#  'atithi',
#  'atithiyon',
#  'atiprabhavit',
#  'atiranjit',
#  'atirikt',
#  'ativadiyon',
#  'ativishisht',
#  'ativrushti',
#  'atishay',
#  'atishyokti',
#  'atishighr',
#  'atishiyoktipurn',
#  'atisamvedansheel',
#  'atit',
#  'atulniy',
#  'atript',
#  'atyant',
#  'atyadhik',
#  'atyalp',
#  'atyachar',
#  'atyachari',
#  'atyacharon',
#  'atyadhik',
#  'atyadhunik',
#  'atyavashyak',
#  'atri',
#  'atri',
#  'atre',
#  'athah',
#  'athaiya',
#  'authority',
#  'adan',
#  'adnan',
#  'adnani',
#  'adbhut',
#  'adamy',
#  'adar',
#  'adrak',
#  'adla',
#  'adlabadli',
#  'adakaraon',
#  'adakari',
#  'adani',
#  'adayagi',
#  'adalat',
#  'adalati',
#  'adalten',
#  'adalton',
#  'aditi',
#  'adur',
#  'adurdarshita',
#  'adrishy',
#  'adbhut',
#  'adbhut',
#  'advitiya',
#  'adhmara',
#  'adharm',
#  'adhik',
#  'adhikta',
#  'adhikar',
#  'adhikaran',
#  'adhikaranon',
#  'adhikansh',
#  'adhikanshat',
#  'adhikadhik',
#  'adhikar',
#  'adhikarkshetra',
#  'adhikarhin',
#  'adhikarik',
#  'adhikarita',
#  'adhikariyo',
#  'adhikariyon',
#  'adhikari',
#  'adhikariyon',
#  'adhikaron',
#  'adhikansh',
#  'adhigam',
#  'adhigrahit',
#  'adhigrahan',
#  'adhigrahanon',
#  'adhigrahit',
#  'adhigrahit',
#  'adhinav',
#  'adhinasth',
#  'adhinayakwadi',
#  'adhiniyam',
#  'adhiniyamon',
#  'adhinirnay',
#  'adhipati',
#  'adhipatya',
#  'adhibhar',
#  'adhiya',
#  'adhirath',
#  'adhiraj',
#  'adhivakta',
#  'adhivasi',
#  'adhiveshan',
#  'adhishesh',
#  'adhishtata',
#  'adhishthan',
#  'adhisuchna',
#  'adhisuchit',
#  'adhikshak',
#  'adhigrahan',
#  'adhin',
#  'adhinta',
#  'adhinsth',
#  'adhir',
#  'adhirta',
#  'adhura',
#  'adhuri',
#  'adhur',
#  'adhyaksh',
#  'adhyakshta',
#  'adhyaksha',
#  'adhshiya',
#  'adhyakshon',
#  'adhyan',
#  'adhyayan',
#  'adhyayankarta',
#  'adhyaynshil',
#  'adhyayanon',
#  'adhyatmik',
#  'adhyadesh',
#  'adhyadeshon',
#  'adhyapak',
#  'adhyapkon',
#  'adhyapan',
#  'adhyapika',
#  'adhyay',
#  'adhyayon',
#  'adhyeta',
#  'adhyetaon',
#  'adhyksh',
#  'adhyyan',
#  'un',
#  'anantkal',
#  'anantmul',
#  'ankahe',
#  'anginat',
#  'angha',
#  'anjaan',
#  'anjana',
#  'anjani',
#  'anjane',
#  'untold',
#  'andekha',
#  'andekhi',
#  'unknown',
#  'ananya',
#  'anpadh',
#  'unfit',
#  'anban',
#  'unbreakable',
#  'anmol',
#  'unlawful',
#  'anshan',
#  'ansuni',
#  'ansuljha',
#  'ansuljhe',
#  'ansuya',
#  'anhad',
#  'anachar',
#  'anaj',
#  'anajon',
#  'anadipan',
#  'anath',
#  'anathalay',
#  'anathalayon',
#  'anadar',
#  'anadi',
#  'anaam',
#  'anamat',
#  'anamika',
#  'anayas',
#  'anaar',
#  'anarkali',
#  'anarkshit',
#  'anarwala',
#  'anavaran',
#  'anavrishti',
#  'anastasiya',
#  'anichcha',
#  'anichchit',
#  'anichhuk',
#  'anitya',
#  'anidra',
#  'anima',
#  'aniyantrit',
#  'aniyamit',
#  'aniyamitata',
#  'aniruddh',
#  'anirnit',
#  'anil',
#  'anivarya',
#  'anivaryata',
#  'anivaryataon',
#  'anishchay',
#  'anishchit',
#  'anishchita',
#  'anita',
#  'anish',
#  'anu',
#  'anukaran',
#  'anukarniy',
#  'anukalp',
#  'anukulan',
#  'anukrit',
#  'anukram',
#  'anugaman',
#  'anugami',
#  'anugrah',
#  'anuchchhed',
#  'anuchchhedon',
#  'anuj',
#  'anugyapti',
#  'anutha',
#  'anuttarit',
#  'anutpadak',
#  'anudan',
#  'anudanit',
#  'anudanon',
#  'anudarvadi',
#  'anudesh',
#  'anudeshak',
#  'anudeshakon',
#  'anudeshon',
#  'anunay',
#  'anup',
#  'anupam',
#  'anupayukt',
#  'anupayogi',
#  'anuplabdh',
#  'anupasthit',
#  'anupasthiti',
#  'anupat',
#  'anupathin',
#  'anupalan',
#  'anupurak',
#  'anupranit',
#  'anubandh',
#  'anubandhit',
#  'anubandhon',
#  'anubhav',
#  'anubhavhinta',
#  'anubhavi',
#  'anubhavon',
#  'anubha',
#  'anubhag',
#  'anubhagon',
#  'anubhut',
#  'anubhuti',
#  'anubhutiyon',
#  'anumandal',
#  'anumat',
#  'anumati',
#  'anumatiyon',
#  'anuman',
#  'anumanat',
#  'anumanit',
#  'anumanon',
#  'anumodan',
#  'anumodit',
#  'anuyayiyon',
#  'anuyayiyon',
#  'anuyayi',
#  'anurag',
#  'anuradha',
#  'anurup',
#  'anurupta',
#  'anurodh',
#  'anurodhon',
#  'anuwanshiki',
#  'anuvadkon',
#  'anushansa',
#  'anushnsaon',
#  'anushasan',
#  'anushasit',
#  'anushilan',
#  'anushravan',
#  'anushangi',
#  'anushka',
#  'anushthan',
#  'anushthanon',
#  'anusandhan',
#  'anusandhankartaon',
#  'anusandhanon',
#  'anusamrthan',
#  'anusar',
#  'anusar',
#  'anusuchit',
#  'anusuchiyon',
#  'anusuchi',
#  'anutha',
#  'anuthe',
#  'anup',
#  'anupgadh',
#  'anuppur',
#  'anupshahar',
#  'anek',
#  'anekanek',
#  'anekon',
#  'anaitik',
#  'anokha',
#  'anokhi',
#  'anokhe',
#  'anokhepan',
#  'anopcharik',
#  'ann',
#  'annat',
#  'anna',
#  'annamalai',
#  'annu',
#  'anya',
#  'anyatam',
#  'anyatha',
#  'anyanya',
#  'anyayapurn',
#  'anyon',
#  'anveshak',
#  'anveshan',
#  'up',
#  'apang',
#  'apanjikrit',
#  'upgrade',
#  'apchan',
#  'update',
#  'updated',
#  'apattiy',
#  'apdasth',
#  'apna',
#  'apnai',
#  'apnakar',
#  'apnata',
#  'apnati',
#  'apnate',
#  'apnane',
#  'apnaya',
#  'apnayi',
#  'apni',
#  'apne',
#  'apneaap',
#  'apne',
#  'apbhransh',
#  'apman',
#  'apmanjanak',
#  'apmanit',
#  'apar',
#  'apranpar',
#  'apardan',
#  'apra',
#  'aparajit',
#  'aparajita',
#  'apradh',
#  'apraadhbodh',
#  'aparadhmukt',
#  'apradhik',
#  'apradhiyon',
#  'apradhi',
#  'apradhon',
#  'aparigrah',
#  'aparichit',
#  'aparipakv',
#  'aparipakvata',
#  'aparibhashit',
#  'aprimey',
#  'aparivartaniy',
#  'aparivartit',
#  'aprishkrat',
#  'aproksh',
#  'aprna',
#  'apryapt',
#  'apvad',
#  'apvadon',
#  'apvah',
#  'apvyay',
#  'apshisht',
#  'upset',
#  'apharankrta',
#  'apache',
#  'apar',
#  'apartment',
#  'apartments',
#  'apitu',
#  'apilkarta',
#  'apusht',
#  'apuran',
#  'apurv',
#  'apeksha',
#  'apekshaon',
#  'apekshakrit',
#  'apekshit',
#  'apen',
#  'appointment',
#  'opposite',
#  'uptawn',
#  'appam',
#  'upper',
#  'appa',
#  'aprakashit',
#  'aprachalit',
#  'apratim',
#  'apratyaksh',
#  'apratyashit',
#  'apradhan',
#  'aprabhavit',
#  'aprabhavi',
#  'apramanik',
#  'apramanit',
#  'apravasiyon',
#  'apravasi',
#  'aprashikshit',
#  'aprasann',
#  'aprakratik',
#  'aprapya',
#  'apramanik',
#  'aprasangik',
#  'apriya',
#  'april',
#  'applied',
#  'application',
#  'aps',
#  'apsraon',
#  'afjal',
#  'aftab',
#  'aflatoon',
#  'afwah',
#  'afwahon',
#  'afsar',
#  'afsarshahi',
#  'afsaron',
#  'afghanistan',
#  'afghani',
#  'afgaanon',
#  'afeem',
#  'affair',
#  'affairs',
#  'africa',
#  'african',
#  'afriki',
#  'ab',
#  'about',
#  'ababeel',
#  'abu',
#  'abe',
#  'abohar',
#  'abd',
#  'abdali',
#  'abdur',
#  'abdul',
#  'abdula',
#  'abdulla',
#  'abraham',
#  'abhdrata',
#  'abhay',
#  'abhage',
#  'abhav',
#  'abhikaran',
#  'abhikartaon',
#  'abhikalpana',
#  'abhikriya',
#  'abhikriyaon',
#  'abhijaty',
#  'abhigyan',
#  'abhidha',
#  'abhinandan',
#  'abhinay',
#  'abhinayon',
#  'abhinav',
#  'abhinit',
#  'abhineta',
#  'abhinetaon',
#  'abhinetriyon',
#  'abhinetri',
#  'abhiney',
#  'abhinn',
#  'abhipray',
#  'abhipret',
#  'abhiprerit',
#  'abhibhavak',
#  'abhibhavakon',
#  'abhibhashak',
#  'abhibhashan',
#  'abhibhut',
#  'abhimanyu',
#  'abhiman',
#  'abhimani',
#  'abhiyantran',
#  'abhiyantriki',
#  'abhiyan',
#  'abhiyanon',
#  'abhiyukt',
#  'abhiyukton',
#  'abhiyog',
#  'abhiyojak',
#  'abhiyojan',
#  'abhiruchi',
#  'abhilasha',
#  'abhilekh',
#  'abhilekhagar',
#  'abhilekhiy',
#  'abhilekhon',
#  'abhivinyas',
#  'abhivridhi',
#  'abhivedan',
#  'abhivyakt',
#  'abhivyakti',
#  'abhivyaktiyan',
#  'abhivyaktiyon',
#  'abhishapt',
#  'abhishek',
#  'abhisaran',
#  'abhisinchit',
#  'abhihit',
#  'abhipsa',
#  'abhisht',
#  'abhukt',
#  'abhutpurv',
#  'abhedy',
#  'abhyankar',
#  'abhyast',
#  'abhyarany',
#  'abhyavedan',
#  'abhyas',
#  'abhyason',
#  'amjad',
#  'aman',
#  'amnaur',
#  'amar',
#  'amarkantak',
#  'amarkant',
#  'amarchand',
#  'amardas',
#  'amarnath',
#  'amarpura',
#  'amrapurkar',
#  'amric',
#  'american',
#  'amriki',
#  'amrish',
#  'amrendra',
#  'amreli',
#  'amroha',
#  'amal',
#  'amlapur',
#  'amant',
#  'amount',
#  'aman',
#  'amanviya',
#  'amanviyta',
#  'amanullah',
#  'amanushik',
#  'amit',
#  'amitabh',
#  'amila',
#  'amin',
#  'amino',
#  'amiba',
#  'amirat',
#  'amiri',
#  'amiron',
#  'amuman',
#  'amur',
#  'amrit',
#  'amritpan',
#  'amritlal',
#  'amritwani',
#  'amritsar',
#  'amrita',
#  'amethi',
#  'america',
#  'amerikiyon',
#  'ameriki',
#  'ammonium',
#  'ammonia',
#  'amora',
#  'amma',
#  'amman',
#  'ammaal',
#  'amal',
#  'amliy',
#  'amliyata',
#  'amlon',
#  'ayan',
#  'ayansh',
#  'ayask',
#  'ayaj',
#  'ayaaz',
#  'ayaan',
#  'ayub',
#  'ayog',
#  'ayogytaa',
#  'ayojit',
#  'ayonij',
#  'ayyadurai',
#  'ayyappa',
#  'ayyash',
#  'ayyashi',
#  'arnab',
#  'arabpati',
#  'arabon',
#  'aramaan',
#  'armani',
#  'arva',
#  'arvind',
#  'arshad',
#  'arhar',
#  'arajakta',
#  'arajaktavadi',
#  'arafat',
#  'aravali',
#  'arinjay',
#  'arijit',
#  'arisht',
#  'arihant',
#  'aruchi',
#  'aruchikar',
#  'aruna',
#  'arunachal',
#  'arun',
#  'arunachal',
#  'arabic',
#  'arera',
#  'areraj',
#  'arora',
#  'ark',
#  'archadiya',
#  'archana',
#  'arjit',
#  'argentina',
#  'arthkari',
#  'arthpoorn',
#  'arthvyavastha',
#  'arthvyavasthaon',
#  'arthashastra',
#  'arthashastriyon',
#  'arthashastri',
#  'arthhin',
#  'arddh',
#  'arddhsarkari',
#  'arddhsainik',
#  'ardh',
#  'ardhchandr',
#  'ardhvaarshik',
#  'earn',
#  'earnest',
#  'arpan',
#  'early',
#  'arshi',
#  'arse',
#  'arh',
#  'arhata',
#  'alnkarn',
#  'alankaranon',
#  'alankrit',
#  'alaktara',
#  'alaknanda',
#  'alakshit',
#  'alakh',
#  'alag',
#  'algebra',
#  'alfred',
#  'albatta',
#  'albert',
#  'albama',
#  'albeli',
#  'almariyon',
#  'almari',
#  'alerts',
#  'alvar',
#  'alvida',
#  'alsi',
#  'alstayer',
#  'alide',
#  'alauddin',
#  'aladin',
#  'alarm',
#  'alava',
#  'aliganj',
#  'aligarh',
#  'alipur',
#  'alipurdawar',
#  'alibag',
#  'alibaba',
#  'alisha',
#  'alexander',
#  'alex',
#  'alokapriyata',
#  'alaukik',
#  'alcohol',
#  'alcoholic',
#  'aljaimar',
#  'alter',
#  'ultimate',
#  'altimatum',
#  'alto',
#  'ultra',
#  'ultraviolet',
#  'ultrasound',
#  'alpakalik',
#  'alpakalin',
#  'alpana',
#  'alpsankhyak',
#  'alpsankyakvad',
#  'alpasankhyko',
#  'alpine',
#  'alpayu',
#  'alpavdhi',
#  'alpahar',
#  'alfred',
#  'alfriend',
#  'albania',
#  'albuquerque',
#  'albania',
#  'almora',
#  'aluminium',
#  'allama',
#  'allah',
#  'allu',
#  'alhad',
#  'avgat',
#  'avchetan',
#  'avagya',
#  ...]

# %%
params = {
    'num_encode_layers' : 1,
    'num_decode_layers' : 1,
    'cell type' : 'RNN' ,
    'data' : data,
    
    
}

# %% [markdown]
# # Romanized

# %%
ta_rom = dict()
ta_rom['rejoined'] = pd.read_csv('/content/dakshina_dataset_v1.0/ta/romanized/ta.romanized.rejoined.tsv', sep='\t', header=None, error_bad_lines=False)
ta_rom['rejoined_aligned_cased'] = pd.read_csv('/content/dakshina_dataset_v1.0/ta/romanized/ta.romanized.rejoined.aligned.cased_nopunct.tsv', sep='\t', header=None, error_bad_lines=False) 
ta_rom['rejoined_aligned'] = pd.read_csv('/content/dakshina_dataset_v1.0/ta/romanized/ta.romanized.rejoined.aligned.tsv', sep='\t', header=None, error_bad_lines=False)
ta_rom['split'] = pd.read_csv('/content/dakshina_dataset_v1.0/ta/romanized/ta.romanized.split.tsv', sep='\t', header=None, error_bad_lines=False)
# Out:
# b'Skipping line 1096: expected 2 fields, saw 3\nSkipping line 1581: expected 2 fields, saw 3\n'
# b'Skipping line 33794: expected 2 fields, saw 3\nSkipping line 33795: expected 2 fields, saw 3\nSkipping line 33796: expected 2 fields, saw 3\nSkipping line 33798: expected 2 fields, saw 3\nSkipping line 33799: expected 2 fields, saw 3\nSkipping line 33801: expected 2 fields, saw 3\nSkipping line 33802: expected 2 fields, saw 3\nSkipping line 33803: expected 2 fields, saw 3\n'
# b'Skipping line 11317: expected 2 fields, saw 4\nSkipping line 16502: expected 2 fields, saw 4\nSkipping line 32577: expected 2 fields, saw 3\nSkipping line 32578: expected 2 fields, saw 3\nSkipping line 32579: expected 2 fields, saw 3\nSkipping line 32581: expected 2 fields, saw 3\nSkipping line 32582: expected 2 fields, saw 3\nSkipping line 32584: expected 2 fields, saw 3\nSkipping line 32585: expected 2 fields, saw 3\nSkipping line 32586: expected 2 fields, saw 3\n'
# b'Skipping line 1108: expected 7 fields, saw 9\nSkipping line 1597: expected 7 fields, saw 9\n'

# %%
list(ta_rom['rejoined'].iloc[0, 0])[:10]
# Out:
# ['ர', 'ே', 'ட', 'ி', 'ய', 'ோ', ' ', 'அ', 'த', 'ி']

# %%
ta_rom['rejoined_aligned_cased']
# Out:
#                   0            1
# 0            ரேடியோ        radio
# 1         அதிர்வெண்     athirven
# 2       முடுக்கிகள்   mudikkigal
# 3          துகள்கள்    thugalkal
# 4          நேரடியாக   neradiyaga
# ...             ...          ...
# 104779   இவ்விதழின்  ivvithazhin
# 104780         விலை        vilai
# 104781       ரூபாய்      roobaay
# 104782         1.00         1.00
# 104783         </s>         </s>
#
# [104784 rows x 2 columns]

# %%
ta_rom['rejoined_aligned']
# Out:
#                    0            1
# 0             ரேடியோ        Radio
# 1          அதிர்வெண்     athirven
# 2       முடுக்கிகள்,  mudikkigal,
# 3           துகள்கள்    thugalkal
# 4           நேரடியாக   neradiyaga
# ...              ...          ...
# 103538    இவ்விதழின்  ivvithazhin
# 103539          விலை        vilai
# 103540        ரூபாய்      roobaay
# 103541          1.00         1.00
# 103542          </s>         </s>
#
# [103543 rows x 2 columns]

# %%
ta_rom['split']
# Out:
#                                                       0   1  ...   5    6
# 0     ரேடியோ அதிர்வெண் முடுக்கிகள், துகள்கள் நேரடியா...   6  ... NaN  NaN
# 1     மான் விளையாடிக்கொண்டு வந்து உன்னை மோதினால் உன்...  21  ... NaN  NaN
# 2                                             அமிர்தகழி   1  ... NaN  NaN
# 3     மோகன் லால் குப்தா ஜெய்ப்பூரின் முன்னாள் மேயராக...  12  ... NaN  NaN
# 4                      தில்லி மாநில கூட்டுறவு வங்கி லி.   5  ... NaN  NaN
# ...                                                 ...  ..  ...  ..  ...
# 9982  என்றாலும் வில்லியம் இறந்த பிறகான கரோலினின் பணி...  27  ... NaN  NaN
# 9983  தொல்பொருளியல் அச்சகம் (Archaeopress) என்பது இங...  14  ... NaN  NaN
# 9984  மலைய நாட்டு மன்னனை மலாடர் கோமான் என்று சங்கப்ப...   8  ... NaN  NaN
# 9985  அப்படையின் தொகை மிக அருகி இருந்ததோடு, அதனிடம் ...  12  ... NaN  NaN
# 9986  தொண்டன் இலங்கை, திருகோணமலையிலிருந்து 1970ம் ஆண...  15  ... NaN  NaN
#
# [9987 rows x 7 columns]
